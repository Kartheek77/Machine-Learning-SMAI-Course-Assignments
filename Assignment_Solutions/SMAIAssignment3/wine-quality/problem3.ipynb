# %% [markdown]
# # part1(One Vs All)

# %%
import pandas as pd
import numpy as np
#WineData = pd.read_csv('data.csv',sep=';',index_col = False)
#train = WineData.sample(frac = 0.8)
#val = WineData.loc[~WineData.index.isin(train.index)]
#train.to_csv('UsedTrainingDataForWineDs.csv',sep=';',index = False)
#val.to_csv('UsedValidationDataForWineDs.csv',sep=';',index = False)
train = pd.read_csv('UsedTrainingDataForWineDs.csv',sep=';',index_col = False)
val = pd.read_csv('UsedValidationDataForWineDs.csv',sep=';',index_col = False)
temptrain = train.loc[:,train.columns != 'quality"""']
new_coltrain = [1]*len(train)
temptrain.insert(loc=0, column='intercept', value =new_coltrain)
trainXmatrix = temptrain.values
trainXmatrix -= np.mean(trainXmatrix,axis = 0)
trainXmatrix[:,1:] /= np.std(trainXmatrix.astype(float),axis = 0)[1:]
trainXmatrix[:,0] = 1

tempval = val.loc[:,val.columns != 'quality"""']
new_colval = [1]*len(val)
tempval.insert(loc=0, column='intercept', value=new_colval)
valXmatrix = tempval.values
valXmatrix -= np.mean(valXmatrix,axis = 0)
valXmatrix[:,1:] /= np.std(valXmatrix.astype(float),axis = 0)[1:]
valXmatrix[:,0] = 1

numOfSamples,numOfdimPlusOne = trainXmatrix.shape
#numOfSamples,numOfdimPlusOne
def getSigmoid(x,theta):
    x = np.array(x)
    theta = np.array(theta)
    k = theta@x
    return 1/(1+np.exp(-k))

conMatrix ={}
precisionForAllClasses = 0
for eachvalue in np.unique(train['quality"""']):
    trainYvector = np.array([1.0 if x == eachvalue else 0.0 for x in train['quality"""']])
    valYvector = np.array([1.0 if x == eachvalue else 0.0 for x in val['quality"""']])
    iterations = 0
    theta = np.array([0.5]*numOfdimPlusOne) #initialization
    #alpha = 0.0005
    #alpha = 0.05
    residual = 10
    likelyHood = 1000
    #while iterations <50:
    while residual > 0.001:
        beforetheta = theta.copy()
        beforelikelyHood = likelyHood
        print("iteration is "+str(iterations))
        #print("theta is "+str(theta))        
        likelyHood = 0
        iterations += 1
        #alpha = (0.5)/((iterations**(0.5))+1)
        for k in range(0,numOfSamples):
            tempSigmoid = getSigmoid(trainXmatrix[k,:],theta)
            if trainYvector[k] == 1.0:
                if tempSigmoid > 0:
                    likelyHood += np.log(tempSigmoid)
                else:
                    likelyHood -= 1000
            else:
                if (1-tempSigmoid) > 0:
                    likelyHood += np.log(1-tempSigmoid)   
                else:
                    likelyHood -= 1000                
        print("likelyHood is "+str(likelyHood))  
       
        for j in range(0,numOfdimPlusOne):
            tempj = 0
            for i in range(0,numOfSamples):
                tempj += (alpha*(trainYvector[i]-getSigmoid(trainXmatrix[i,:],theta))*trainXmatrix[i,j])
            theta[j] += tempj   
        #esidual = np.linalg.norm(theta-beforetheta)
        residual = np.linalg.norm(likelyHood-beforelikelyHood)
        
    Ypredicted = np.array([0]*len(valYvector))
    for i in range(0,len(valXmatrix)):
        if getSigmoid(valXmatrix[i,:],theta)> 0.5:
            Ypredicted[i] = 1.0
        else:
            Ypredicted[i] = 0.0  
    conMatrix[eachvalue] = pd.crosstab(Ypredicted,valYvector)
    print(conMatrix[eachvalue])
    
for i in conMatrix:
    print("value is "+str(i))
    print("its confusion matrix is")
    print(conMatrix[i])
# Out:
# iteration is 0
# likelyHood is -4575.167786312536
# iteration is 1
# likelyHood is -476.59023551936673
# iteration is 2
# likelyHood is -462.8667690699019
# iteration is 3
# likelyHood is -449.1435108954519
# iteration is 4
# likelyHood is -435.5243646732516
# iteration is 5
# likelyHood is -425.3118945730147
# iteration is 6
# likelyHood is -418.5489529757197
# iteration is 7
# likelyHood is -411.89209535043494
# iteration is 8
# likelyHood is -405.2633909465426
# iteration is 9
# likelyHood is -398.6450249764133
# iteration is 10
# likelyHood is -392.0308735953101
# iteration is 11
# likelyHood is -385.418518931104
# iteration is 12
# likelyHood is -378.80697188739543
# iteration is 13
# likelyHood is -372.1959353205831
# iteration is 14
# likelyHood is -365.5860602361809
# iteration is 15
# likelyHood is -358.98279461214236
# iteration is 16
# likelyHood is -352.42311106835723
# iteration is 17
# likelyHood is -346.1167208695353
# iteration is 18
# likelyHood is -340.61366077099694
# iteration is 19
# likelyHood is -335.9518033907945
# iteration is 20
# likelyHood is -331.662670123578
# iteration is 21
# likelyHood is -327.5930275047702
# iteration is 22
# likelyHood is -323.7035117670005
# iteration is 23
# likelyHood is -319.953150135614
# iteration is 24
# likelyHood is -316.29433385786837
# iteration is 25
# likelyHood is -312.6890218756695
# iteration is 26
# likelyHood is -309.1132234891692
# iteration is 27
# likelyHood is -305.55347846243797
# iteration is 28
# likelyHood is -302.00260073214804
# iteration is 29
# likelyHood is -298.4568052326639
# iteration is 30
# likelyHood is -294.9140836394145
# iteration is 31
# likelyHood is -291.3733500997603
# iteration is 32
# likelyHood is -287.83400531492845
# iteration is 33
# likelyHood is -284.29571688486453
# iteration is 34
# likelyHood is -280.7583104130334
# iteration is 35
# likelyHood is -277.2217192341281
# iteration is 36
# likelyHood is -273.6859687880905
# iteration is 37
# likelyHood is -270.151187133121
# iteration is 38
# likelyHood is -266.6176432531954
# iteration is 39
# likelyHood is -263.0858241519393
# iteration is 40
# likelyHood is -259.55657339454143
# iteration is 41
# likelyHood is -256.0313299404414
# iteration is 42
# likelyHood is -252.51252554883942
# iteration is 43
# likelyHood is -249.00420682844754
# iteration is 44
# likelyHood is -245.51288768938034
# iteration is 45
# likelyHood is -242.0483732201362
# iteration is 46
# likelyHood is -238.62371479229026
# iteration is 47
# likelyHood is -235.25315565266624
# iteration is 48
# likelyHood is -231.94873731392377
# iteration is 49
# likelyHood is -228.71906269190467
# iteration is 50
# likelyHood is -225.57067572761966
# iteration is 51
# likelyHood is -222.5079520815914
# iteration is 52
# likelyHood is -219.53199573082415
# iteration is 53
# likelyHood is -216.64187014131883
# iteration is 54
# likelyHood is -213.83731090117095
# iteration is 55
# likelyHood is -211.11987346337173
# iteration is 56
# likelyHood is -208.49114729277062
# iteration is 57
# likelyHood is -205.94980918978658
# iteration is 58
# likelyHood is -203.49084213817147
# iteration is 59
# likelyHood is -201.10760894162985
# iteration is 60
# likelyHood is -198.79425089833282
# iteration is 61
# likelyHood is -196.54662855175252
# iteration is 62
# likelyHood is -194.36210586799535
# iteration is 63
# likelyHood is -192.23893907510111
# iteration is 64
# likelyHood is -190.1756543725573
# iteration is 65
# likelyHood is -188.17055778382232
# iteration is 66
# likelyHood is -186.22144939208192
# iteration is 67
# likelyHood is -184.3255692367751
# iteration is 68
# likelyHood is -182.47974580175742
# iteration is 69
# likelyHood is -180.6806714987151
# iteration is 70
# likelyHood is -178.92521457266992
# iteration is 71
# likelyHood is -177.21069447578284
# iteration is 72
# likelyHood is -175.5350817381905
# iteration is 73
# likelyHood is -173.8971139071107
# iteration is 74
# likelyHood is -172.29633435989706
# iteration is 75
# likelyHood is -170.73306012529963
# iteration is 76
# likelyHood is -169.20827605477788
# iteration is 77
# likelyHood is -167.72344741904527
# iteration is 78
# likelyHood is -166.28025195071035
# iteration is 79
# likelyHood is -164.88025842993528
# iteration is 80
# likelyHood is -163.52461042436133
# iteration is 81
# likelyHood is -162.213787313274
# iteration is 82
# likelyHood is -160.94749377000915
# iteration is 83
# likelyHood is -159.72468279648072
# iteration is 84
# likelyHood is -158.54367531649615
# iteration is 85
# likelyHood is -157.40232330382472
# iteration is 86
# likelyHood is -156.2981727104296
# iteration is 87
# likelyHood is -155.2286022197651
# iteration is 88
# likelyHood is -154.19093096655683
# iteration is 89
# likelyHood is -153.18249798265268
# iteration is 90
# likelyHood is -152.20071933822567
# iteration is 91
# likelyHood is -151.2431286431708
# iteration is 92
# likelyHood is -150.30740510176406
# iteration is 93
# likelyHood is -149.3913919167475
# iteration is 94
# likelyHood is -148.4931069173056
# iteration is 95
# likelyHood is -147.6107468057189
# iteration is 96
# likelyHood is -146.74268620937622
# iteration is 97
# likelyHood is -145.88747263076482
# iteration is 98
# likelyHood is -145.04381831152338
# iteration is 99
# likelyHood is -144.21058992847327
# iteration is 100
# likelyHood is -143.38679691604733
# iteration is 101
# likelyHood is -142.5715790727621
# iteration is 102
# likelyHood is -141.76419397342366
# iteration is 103
# likelyHood is -140.9640045841689
# iteration is 104
# likelyHood is -140.17046736963587
# iteration is 105
# likelyHood is -139.38312109200945
# iteration is 106
# likelyHood is -138.6015764294288
# iteration is 107
# likelyHood is -137.8255064841652
# iteration is 108
# likelyHood is -137.0546382068315
# iteration is 109
# likelyHood is -136.28874472942434
# iteration is 110
# likelyHood is -135.52763857544844
# iteration is 111
# likelyHood is -134.77116569809792
# iteration is 112
# likelyHood is -134.01920028619264
# iteration is 113
# likelyHood is -133.27164027105601
# iteration is 114
# likelyHood is -132.52840346487582
# iteration is 115
# likelyHood is -131.78942426129916
# iteration is 116
# likelyHood is -131.05465083143162
# iteration is 117
# likelyHood is -130.32404275228768
# iteration is 118
# likelyHood is -129.59756900961494
# iteration is 119
# likelyHood is -128.87520632239733
# iteration is 120
# likelyHood is -128.1569377419159
# iteration is 121
# likelyHood is -127.44275148377153
# iteration is 122
# likelyHood is -126.7326399565334
# iteration is 123
# likelyHood is -126.02659895561506
# iteration is 124
# likelyHood is -125.32462699543687
# iteration is 125
# likelyHood is -124.62672475698442
# iteration is 126
# likelyHood is -123.93289463140641
# iteration is 127
# likelyHood is -123.24314034342581
# iteration is 128
# likelyHood is -122.55746664099186
# iteration is 129
# likelyHood is -121.87587903991532
# iteration is 130
# likelyHood is -121.19838361416673
# iteration is 131
# likelyHood is -120.52498682414243
# iteration is 132
# likelyHood is -119.85569537658769
# iteration is 133
# likelyHood is -119.19051611098166
# iteration is 134
# likelyHood is -118.52945590814069
# iteration is 135
# likelyHood is -117.87252161755806
# iteration is 136
# likelyHood is -117.21972000062867
# iteration is 137
# likelyHood is -116.57105768742782
# iteration is 138
# likelyHood is -115.92654114512241
# iteration is 139
# likelyHood is -115.2861766564404
# iteration is 140
# likelyHood is -114.64997030689017
# iteration is 141
# likelyHood is -114.01792797965159
# iteration is 142
# likelyHood is -113.39005535723167
# iteration is 143
# likelyHood is -112.7663579291242
# iteration is 144
# likelyHood is -112.1468410048298
# iteration is 145
# likelyHood is -111.53150973167743
# iteration is 146
# likelyHood is -110.92036911696674
# iteration is 147
# likelyHood is -110.31342405400626
# iteration is 148
# likelyHood is -109.7106793516592
# iteration is 149
# likelyHood is -109.1121397670523
# iteration is 150
# likelyHood is -108.5178100411223
# iteration is 151
# likelyHood is -107.92769493668266
# iteration is 152
# likelyHood is -107.34179927872607
# iteration is 153
# likelyHood is -106.76012799665408
# iteration is 154
# likelyHood is -106.18268616815956
# iteration is 155
# likelyHood is -105.60947906445855
# iteration is 156
# likelyHood is -105.04051219658203
# iteration is 157
# likelyHood is -104.47579136242692
# iteration is 158
# likelyHood is -103.91532269425524
# iteration is 159
# likelyHood is -103.35911270633602
# iteration is 160
# likelyHood is -102.8071683423973
# iteration is 161
# likelyHood is -102.25949702257263
# iteration is 162
# likelyHood is -101.71610668950102
# iteration is 163
# likelyHood is -101.17700585324413
# iteration is 164
# likelyHood is -100.64220363468202
# iteration is 165
# likelyHood is -100.11170980704301
# iteration is 166
# likelyHood is -99.58553483522827
# iteration is 167
# likelyHood is -99.06368991259949
# iteration is 168
# likelyHood is -98.54618699488137
# iteration is 169
# likelyHood is -98.03303883088111
# iteration is 170
# likelyHood is -97.52425898969031
# iteration is 171
# likelyHood is -97.01986188408642
# iteration is 172
# likelyHood is -96.51986278984673
# iteration is 173
# likelyHood is -96.02427786071442
# iteration is 174
# likelyHood is -95.53312413877107
# iteration is 175
# likelyHood is -95.04641956001208
# iteration is 176
# likelyHood is -94.56418295491503
# iteration is 177
# likelyHood is -94.0864340438545
# iteration is 178
# likelyHood is -93.6131934272184
# iteration is 179
# likelyHood is -93.14448257012913
# iteration is 180
# likelyHood is -92.68032378169138
# iteration is 181
# likelyHood is -92.22074018873414
# iteration is 182
# likelyHood is -91.76575570403492
# iteration is 183
# likelyHood is -91.31539498905654
# iteration is 184
# likelyHood is -90.86968341125186
# iteration is 185
# likelyHood is -90.42864699603147
# iteration is 186
# likelyHood is -89.99231237351478
# iteration is 187
# likelyHood is -89.56070672021686
# iteration is 188
# likelyHood is -89.13385769585163
# iteration is 189
# likelyHood is -88.71179337545692
# iteration is 190
# likelyHood is -88.29454217707259
# iteration is 191
# likelyHood is -87.88213278522251
# iteration is 192
# likelyHood is -87.4745940704693
# iteration is 193
# likelyHood is -87.07195500532427
# iteration is 194
# likelyHood is -86.67424457681335
# iteration is 195
# likelyHood is -86.2814916959978
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d4dcb647a3f5> in <module>
#      69             tempj = 0
#      70             for i in range(0,numOfSamples):
# ---> 71                 tempj += (alpha*(trainYvector[i]-getSigmoid(trainXmatrix[i,:],theta))*trainXmatrix[i,j])
#      72             theta[j] += tempj
#      73         #esidual = np.linalg.norm(theta-beforetheta)
#
# <ipython-input-2-d4dcb647a3f5> in getSigmoid(x, theta)
#      27 #numOfSamples,numOfdimPlusOne
#      28 def getSigmoid(x,theta):
# ---> 29     x = np.array(x)
#      30     theta = np.array(theta)
#      31     k = theta@x
#
# KeyboardInterrupt:

# %%
temp1 = WineData
kolo = dict(zip(Counter(temp1['quality"""']).keys(),Counter(temp1['quality"""']).values())) 
print(kolo)
temp1 = train
kolo = dict(zip(Counter(temp1['quality"""']).keys(),Counter(temp1['quality"""']).values())) 
print(kolo)
temp1 = val
kolo = dict(zip(Counter(temp1['quality"""']).keys(),Counter(temp1['quality"""']).values())) 
print(kolo)

# %%
np.unique(train['quality"""'])
from collections import Counter

 # equals to list(set(words))


for eachvalue in np.unique(train['quality"""']):
    print(eachvalue)
    trainYvector = np.array([1.0 if x == eachvalue else 0.0 for x in train['quality"""']])
    print(Counter(trainYvector).keys())
    print(Counter(trainYvector).values())
    valYvector = np.array([1.0 if x == eachvalue else 0.0 for x in val['quality"""']])
    print(np.unique(valYvector))
    
col_0  0.0  1.0
row_0          
0      878    4
col_0  0.0  1.0
row_0          
0      852   30
col_0  0.0  1.0
row_0          
0      556  163
1       68   95
col_0  0.0  1.0
row_0          
0      345  264
1      124  149
col_0  0.0  1.0
row_0          
0      716  125
1       19   22
col_0  0.0  1.0
row_0          
0      853   29
col_0  0.0  1.0
row_0          
0      881    1

((878/882)+(852/882)+((556+95)/882)+((556+95)/882)+((345+149)/882)+((716+22)/882)+(853/882)+(881/882))/7
value is 3
its confusion matrix is
col_0  0.0  1.0
row_0          
0      878    4
value is 4
its confusion matrix is
col_0  0.0  1.0
row_0          
0      852   30
value is 5
its confusion matrix is
col_0  0.0  1.0
row_0          
0      556  163
1       68   95
value is 6
its confusion matrix is
col_0  0.0  1.0
row_0          
0      345  264
1      124  149
value is 7
its confusion matrix is
col_0  0.0  1.0
row_0          
0      716  125
1       19   22
value is 8
its confusion matrix is
col_0  0.0  1.0
row_0          
0      853   29
value is 9
its confusion matrix is
col_0  0.0  1.0
row_0          
0      881    1


{3: col_0  0.0  1.0
 row_0          
 0      878    4, 4: col_0  0.0  1.0
 row_0          
 0      852   30, 5: col_0  0.0  1.0
 row_0          
 0      556  163
 1       68   95, 6: col_0  0.0  1.0
 row_0          
 0      345  264
 1      124  149, 7: col_0  0.0  1.0
 row_0          
 0      716  125
 1       19   22, 8: col_0  0.0  1.0
 row_0          
 0      853   29, 9: col_0  0.0  1.0
 row_0          
 0      881    1}

((878/882)+(852/882)+((556+95)/882)+((556+95)/882)+((345+149)/882)+((716+22)/882)+(853/882)+(881/882))/7 = 0.9714933592484615
(((556+95)/882)+((556+95)/882)+((345+149)/882)+((716+22)/882))/4 = 0.7182539682539684

# %% [markdown]
# # Part2(One vs One)

# %%
import pandas as pd
import numpy as np
#WineData = pd.read_csv('data.csv',sep=';',index_col = False)
#WineData.head()
#del AdmissionData['Serial No.']
#ran = np.random.rand(len(AdmissionData)) < 0.8
#train = AdmissionData[ran]
#val = AdmissionData[~ran]
#train = WineData.sample(frac = 0.8)
#val = WineData.loc[~WineData.index.isin(train.index)]
#train.to_csv('UsedTrainingDataForAdmissionDs.csv',sep=';',index = False)
#val.to_csv('UsedValidationDataForAdmissionDs.csv',sep=';',index = False)
train = pd.read_csv('UsedTrainingDataForWineDs.csv',sep=';',index_col = False)
val = pd.read_csv('UsedValidationDataForWineDs.csv',sep=';',index_col = False)
#train = pd.read_csv('UsedTrainingDataForAdmissionDs.csv',sep=',',index_col = False)
#val = pd.read_csv('UsedValidationDataForAdmissionDs.csv',sep=',',index_col = False)
#np.unique(train['quality"""'])
for i in train.index:
    train.at[i,'quality"""'] -= 3
for i in val.index:
    val.at[i,'quality"""'] -= 3
#np.unique(train['quality"""'])
temptrain = train.loc[:,train.columns != 'quality"""']
new_coltrain = [1]*len(train)
temptrain.insert(loc=0, column='intercept', value =new_coltrain)
trainXmatrix = temptrain.values
trainXmatrix -= np.mean(trainXmatrix,axis = 0)
trainXmatrix[:,1:] /= np.std(trainXmatrix.astype(float),axis = 0)[1:]
trainXmatrix[:,0] = 1

tempval = val.loc[:,val.columns != 'quality"""']
new_colval = [1]*len(val)
tempval.insert(loc=0, column='intercept', value=new_colval)
valXmatrix = tempval.values
valXmatrix -= np.mean(valXmatrix,axis = 0)
valXmatrix[:,1:] /= np.std(valXmatrix.astype(float),axis = 0)[1:]
valXmatrix[:,0] = 1

numOfSamples,numOfdimPlusOne = trainXmatrix.shape
#numOfSamples,numOfdimPlusOne

theta = np.array([np.array([0.5]*numOfdimPlusOne)]*(len(np.unique(train['quality"""']))-1))
#theta.shape

def getSigmoid(x,theta,k):
    #x = np.array(x)
    #theta = np.array(theta)
    numer = np.exp(theta[k]@x)
    denom = 1
    for index in range(0,len(np.unique(train['quality"""']))-1):
        denom += np.exp(theta[index]@x)   
    return numer/denom

valYvector = np.array(val['quality"""'].copy())

# %% [markdown]
# Convergedtheta = np.array([[ 0.83078752,  0.61170823,  0.86434487,  0.42589804,  0.40172731,
#          0.58952366,  0.25183323,  0.39515996,  0.55013274,  0.47169646,
#          0.46386952,  0.38771927],
#        [ 2.65926724,  0.59296356,  0.79548132,  0.38460576,  0.50019212,
#          0.76580049,  0.32927432,  0.74481794,  0.97924027,  0.37003593,
#          0.30668897, -0.36659851],
#        [ 3.88904982,  0.40768877,  0.14904719,  0.5251274 ,  0.55800554,
#          0.47123907,  0.47063105,  0.40479518,  0.44967958,  0.41350013,
#          0.47143144,  0.59351791],
#        [ 2.03246134,  0.38867073,  0.18400969,  0.45490527,  0.29616396,
#          0.05572453,  0.45353791,  0.16459671, -0.0728328 ,  0.65185923,
#          0.61588997,  1.25696314],
#        [ 0.85174006,  0.44276617,  0.46792521,  0.49716958,  0.44416778,
#          0.37601619,  0.53172503,  0.400476  ,  0.2916254 ,  0.56778029,
#          0.50512238,  0.8102274 ],
#        [ 0.50945773,  0.50076105,  0.50255141,  0.50348996,  0.49148837,
#          0.48989324,  0.49373858,  0.4910525 ,  0.48446155,  0.51093922,
#          0.49845555,  0.51969096]])

# %%
#trainYvector = np.array([1.0 if x == eachvalue else 0.0 for x in train['quality"""']])
trainYvector = np.array(train['quality"""'].copy())
#valYvector = np.array([1.0 if x == eachvalue else 0.0 for x in val['quality"""']])
valYvector = np.array(val['quality"""'].copy())
iterations = 0
theta = np.array([np.array([0.5]*numOfdimPlusOne)]*(len(np.unique(train['quality"""']))-1)) #initialization
alpha = 0.00005
residual = 10
likelyHood = 1000
#while iterations <50:
iterations = 0
alpha = 0.0005
while residual > 0.0001:    
    #beforetheta = theta.copy()
    beforelikelyHood = likelyHood
    print("iteration is "+str(iterations))
    #print("theta is "+str(theta))
    likelyHood = 0
    iterations += 1
    if iterations>5:
        alpha = 0.00005
    #alpha = (1/((iterations)+1))
    for p in range(0,numOfSamples):
        if trainYvector[p] >0:
            tempSigmoid = getSigmoid(trainXmatrix[p,:],theta,trainYvector[p]-1)
            if tempSigmoid > 0:
                likelyHood += np.log(tempSigmoid)
            else:
                likelyHood -= 1000 
        else:
            tempSum = 0
            for index1 in range(0,len(np.unique(train['quality"""']))-1):
                tempSum += getSigmoid(trainXmatrix[p,:],theta,index1)
            #tempSigmoid = 1-tempSum
            tempSigmoid = (1/1+(tempSum))
            if tempSigmoid > 0:
                likelyHood += np.log(tempSigmoid)
            else:
                likelyHood -= 1000                
    print("likelyHood is "+str(likelyHood))  

    for j in range(0,numOfdimPlusOne):
        for k in range(1,len(np.unique(train['quality"""']))):
            tempj = 0
            for i in range(0,numOfSamples):
                if trainYvector[i] > 0 and trainYvector[i]==k:
                    tempj += (alpha*(1.0-getSigmoid(trainXmatrix[i,:],theta,k-1))*trainXmatrix[i,j])
                if trainYvector[i] == 0: #and trainYvector[i]==k: 
                    tempj += (alpha*(-getSigmoid(trainXmatrix[i,:],theta,k-1))*trainXmatrix[i,j])
            theta[k-1,j] += tempj   
    #esidual = np.linalg.norm(theta-beforetheta)
    residual = np.linalg.norm(likelyHood-beforelikelyHood)/np.abs(beforelikelyHood)
# Out:
# iteration is 0
# likelyHood is -7192.044017484971
# iteration is 1
# likelyHood is -5847.488568566865
# iteration is 2
# likelyHood is -5097.044360358322
# iteration is 3
# likelyHood is -4692.488332958577
# iteration is 4
# likelyHood is -4489.826951229479
# iteration is 5
# likelyHood is -4407.693723350362
# iteration is 6
# likelyHood is -4403.1782603248685
# iteration is 7
# likelyHood is -4399.253068483785
# iteration is 8
# likelyHood is -4395.891618116193
# iteration is 9
# likelyHood is -4393.068680180523
# iteration is 10
# likelyHood is -4390.760259864034
# iteration is 11
# likelyHood is -4388.943533461326
# iteration is 12
# likelyHood is -4387.596788412448
# iteration is 13
# likelyHood is -4386.699366350373
# iteration is 14
# likelyHood is -4386.231609017456
# iteration is 15
# likelyHood is -4386.174806917386

# %%
Ypredicted = np.array([0]*len(valYvector))
for i in range(0,len(valXmatrix)):
    assigned = False
    for j in range(1,len(np.unique(train['quality"""']))):
        if getSigmoid(valXmatrix[i,:],theta,j-1)>(1/7):
            Ypredicted[i] = j
            assigned = True
            break
        elif assigned == False:
            Ypredicted[i] = 0  
conMatrix = pd.crosstab(Ypredicted,valYvector)
print(conMatrix)
# Out:
# col_0  0   1    2    3    4   5  6
# row_0
# 1      0   1    0    1    0   0  0
# 2      4  20  209  199   36   4  1
# 3      0   8   49  212  107  25  0
# 4      0   1    0    1    4   0  0

# %%
#conMatrix[0][1]
sum1 = 0
for i in range(1,5):
    for j in range(0,6):
        if i==j:
            sum1 += conMatrix[i][j] 
print("Accuracy is "+str(sum1/np.sum(np.sum(conMatrix))))
# Out:
# Accuracy is 0.48299319727891155

# %% [markdown]
# # Another approach one vs one

# %%
import pandas as pd
import numpy as np
#WineData = pd.read_csv('data.csv',sep=';',index_col = False)
#train = WineData.sample(frac = 0.8)
#val = WineData.loc[~WineData.index.isin(train.index)]
#train.to_csv('UsedTrainingDataForWineDs.csv',sep=';',index = False)
#val.to_csv('UsedValidationDataForWineDs.csv',sep=';',index = False)
train = pd.read_csv('UsedTrainingDataForWineDs.csv',sep=';',index_col = False)
val = pd.read_csv('UsedValidationDataForWineDs.csv',sep=';',index_col = False)
temptrain = train.loc[:,train.columns != 'quality"""']
new_coltrain = [1]*len(train)
temptrain.insert(loc=0, column='intercept', value =new_coltrain)
trainXmatrix = temptrain.values
trainXmatrix -= np.mean(trainXmatrix,axis = 0)
trainXmatrix[:,1:] /= np.std(trainXmatrix.astype(float),axis = 0)[1:]
trainXmatrix[:,0] = 1

tempval = val.loc[:,val.columns != 'quality"""']
new_colval = [1]*len(val)
tempval.insert(loc=0, column='intercept', value=new_colval)
valXmatrix = tempval.values
valXmatrix -= np.mean(valXmatrix,axis = 0)
valXmatrix[:,1:] /= np.std(valXmatrix.astype(float),axis = 0)[1:]
valXmatrix[:,0] = 1

numOfSamples,numOfdimPlusOne = trainXmatrix.shape
#numOfSamples,numOfdimPlusOne
def getSigmoid(x,theta):
    x = np.array(x)
    theta = np.array(theta)
    k = theta@x
    return 1/(1+np.exp(-k))

# %%
train1 = pd.read_csv('UsedTrainingDataForWineDs.csv',sep=';',index_col = False)
val1 = pd.read_csv('UsedValidationDataForWineDs.csv',sep=';',index_col = False)

# %%
conMatrix ={}
precisionForAllClasses = 0
import itertools  
for eachvalue1 in list(itertools.combinations(np.unique(train1['quality"""']), 2)):
    train = train1.loc[train1['quality"""'].isin(eachvalue1)]
    val = val1.loc[val1['quality"""'].isin(eachvalue1)]
    #train = train1.loc[(train1['quality"""'] == eachvalue1[0]) or (train1['quality"""'] == eachvalue1[1])]
    #val = val1.loc[(val1['quality"""'] == eachvalue1[0]) or (val1['quality"""'] == eachvalue1[1])]
    #print(train)
    temptrain = train.loc[:,train.columns != 'quality"""']
    new_coltrain = [1]*len(train)
    temptrain.insert(loc=0, column='intercept', value =new_coltrain)
    trainXmatrix = temptrain.values
    trainXmatrix -= np.mean(trainXmatrix,axis = 0)
    trainXmatrix[:,1:] /= np.std(trainXmatrix.astype(float),axis = 0)[1:]
    trainXmatrix[:,0] = 1

    tempval = val.loc[:,val.columns != 'quality"""']
    new_colval = [1]*len(val)
    tempval.insert(loc=0, column='intercept', value=new_colval)
    valXmatrix = tempval.values
    valXmatrix -= np.mean(valXmatrix,axis = 0)
    valXmatrix[:,1:] /= np.std(valXmatrix.astype(float),axis = 0)[1:]
    valXmatrix[:,0] = 1

    numOfSamples,numOfdimPlusOne = trainXmatrix.shape  

    
    for eachvalue in np.unique(train['quality"""']):
        trainYvector = np.array([1.0 if x == eachvalue else 0.0 for x in train['quality"""']])
        valYvector = np.array([1.0 if x == eachvalue else 0.0 for x in val['quality"""']])
        iterations = 0
        theta = np.array([0.5]*numOfdimPlusOne) #initialization
        alpha = 0.0005
        #alpha = 0.05
        residual = 10
        likelyHood = 1000
        #while iterations <50:
        while residual > 0.001:
            beforetheta = theta.copy()
            beforelikelyHood = likelyHood
            print("iteration is "+str(iterations))
            #print("theta is "+str(theta))        
            likelyHood = 0
            iterations += 1
            #alpha = (0.5)/((iterations**(0.5))+1)
            for k in range(0,numOfSamples):
                tempSigmoid = getSigmoid(trainXmatrix[k,:],theta)
                if trainYvector[k] == 1.0:
                    if tempSigmoid > 0:
                        likelyHood += np.log(tempSigmoid)
                    else:
                        likelyHood -= 1000
                else:
                    if (1-tempSigmoid) > 0:
                        likelyHood += np.log(1-tempSigmoid)   
                    else:
                        likelyHood -= 1000                
            print("likelyHood is "+str(likelyHood))  

            for j in range(0,numOfdimPlusOne):
                tempj = 0
                for i in range(0,numOfSamples):
                    tempj += (alpha*(trainYvector[i]-getSigmoid(trainXmatrix[i,:],theta))*trainXmatrix[i,j])
                theta[j] += tempj   
            #esidual = np.linalg.norm(theta-beforetheta)
            residual = np.linalg.norm(likelyHood-beforelikelyHood)/np.abs(beforelikelyHood)

        Ypredicted = np.array([0]*len(valYvector))
        for i in range(0,len(valXmatrix)):
            if getSigmoid(valXmatrix[i,:],theta)> 0.5:
                Ypredicted[i] = 1.0
            else:
                Ypredicted[i] = 0.0  
        conMatrix[eachvalue] = pd.crosstab(Ypredicted,valYvector)
        print(conMatrix[eachvalue])
    
for i in conMatrix:
    print("value is "+str(i))
    print("its confusion matrix is")
    print(conMatrix[i])
# Out:
# iteration is 0
# likelyHood is -165.88361701612445
# iteration is 1
# likelyHood is -162.18189309628332
# iteration is 2
# likelyHood is -158.54860885068558
# iteration is 3
# likelyHood is -154.98482113569668
# iteration is 4
# likelyHood is -151.49152040881825
# iteration is 5
# likelyHood is -148.0696222287689
# iteration is 6
# likelyHood is -144.71995886324908
# iteration is 7
# likelyHood is -141.44327114645898
# iteration is 8
# likelyHood is -138.24020073315646
# iteration is 9
# likelyHood is -135.11128289745054
# iteration is 10
# likelyHood is -132.0569400223215
# iteration is 11
# likelyHood is -129.07747591978156
# iteration is 12
# likelyHood is -126.17307111144868
# iteration is 13
# likelyHood is -123.34377918495944
# iteration is 14
# likelyHood is -120.58952432311564
# iteration is 15
# likelyHood is -117.91010008009951
# iteration is 16
# likelyHood is -115.30516945290685
# iteration is 17
# likelyHood is -112.77426626696999
# iteration is 18
# likelyHood is -110.31679786368942
# iteration is 19
# likelyHood is -107.93204904540401
# iteration is 20
# likelyHood is -105.61918720156712
# iteration is 21
# likelyHood is -103.37726850999921
# iteration is 22
# likelyHood is -101.2052450805432
# iteration is 23
# likelyHood is -99.1019728865847
# iteration is 24
# likelyHood is -97.06622031387184
# iteration is 25
# likelyHood is -95.09667714665542
# iteration is 26
# likelyHood is -93.19196380880703
# iteration is 27
# likelyHood is -91.3506406822215
# iteration is 28
# likelyHood is -89.57121733604612
# iteration is 29
# likelyHood is -87.85216151726007
# iteration is 30
# likelyHood is -86.19190777472079
# iteration is 31
# likelyHood is -84.58886561361278
# iteration is 32
# likelyHood is -83.04142710380138
# iteration is 33
# likelyHood is -81.54797389237761
# iteration is 34
# likelyHood is -80.10688359626882
# iteration is 35
# likelyHood is -78.71653557391849
# iteration is 36
# likelyHood is -77.37531609470308
# iteration is 37
# likelyHood is -76.081622940247
# iteration is 38
# likelyHood is -74.83386948273379
# iteration is 39
# likelyHood is -73.63048829165344
# iteration is 40
# likelyHood is -72.46993432243768
# iteration is 41
# likelyHood is -71.35068773866581
# iteration is 42
# likelyHood is -70.271256414728
# iteration is 43
# likelyHood is -69.23017815890283
# iteration is 44
# likelyHood is -68.22602268868474
# iteration is 45
# likelyHood is -67.25739338178276
# iteration is 46
# likelyHood is -66.32292881831488
# iteration is 47
# likelyHood is -65.4213041229481
# iteration is 48
# likelyHood is -64.5512321105276
# iteration is 49
# likelyHood is -63.71146423528871
# iteration is 50
# likelyHood is -62.900791342073525
# iteration is 51
# likelyHood is -62.11804421790928
# iteration is 52
# likelyHood is -61.362093943571274
# iteration is 53
# likelyHood is -60.631852046987376
# iteration is 54
# likelyHood is -59.92627046316627
# iteration is 55
# likelyHood is -59.24434130838775
# iteration is 56
# likelyHood is -58.58509647935994
# iteration is 57
# likelyHood is -57.94760709069038
# iteration is 58
# likelyHood is -57.3309827661556
# iteration is 59
# likelyHood is -56.73437080080001
# iteration is 60
# likelyHood is -56.15695521181039
# iteration is 61
# likelyHood is -55.59795569642835
# iteration is 62
# likelyHood is -55.056626514929484
# iteration is 63
# likelyHood is -54.532255316008786
# iteration is 64
# likelyHood is -54.024161920856415
# iteration is 65
# likelyHood is -53.531697080886524
# iteration is 66
# likelyHood is -53.05424122258995
# iteration is 67
# likelyHood is -52.59120319139616
# iteration is 68
# likelyHood is -52.14201900482578
# iteration is 69
# likelyHood is -51.70615062364486
# iteration is 70
# likelyHood is -51.28308474823876
# iteration is 71
# likelyHood is -50.87233164603542
# iteration is 72
# likelyHood is -50.47342401454713
# iteration is 73
# likelyHood is -50.08591588347067
# iteration is 74
# likelyHood is -49.70938155829686
# iteration is 75
# likelyHood is -49.343414607023334
# iteration is 76
# likelyHood is -48.9876268908374
# iteration is 77
# likelyHood is -48.641647639026054
# iteration is 78
# likelyHood is -48.3051225678684
# iteration is 79
# likelyHood is -47.977713042861176
# iteration is 80
# likelyHood is -47.65909528330601
# iteration is 81
# likelyHood is -47.34895960804339
# iteration is 82
# likelyHood is -47.047009720930184
# iteration is 83
# likelyHood is -46.75296203453115
# iteration is 84
# likelyHood is -46.466545030406614
# iteration is 85
# likelyHood is -46.18749865432974
# iteration is 86
# likelyHood is -45.91557374474826
# iteration is 87
# likelyHood is -45.65053149280952
# iteration is 88
# likelyHood is -45.392142932291584
# iteration is 89
# likelyHood is -45.140188457821786
# iteration is 90
# likelyHood is -44.89445736981208
# iteration is 91
# likelyHood is -44.654747444599
# iteration is 92
# likelyHood is -44.42086452833799
# iteration is 93
# likelyHood is -44.192622153266925
# iteration is 94
# likelyHood is -43.96984117502386
# iteration is 95
# likelyHood is -43.752349429769595
# iteration is 96
# likelyHood is -43.53998140993549
# iteration is 97
# likelyHood is -43.33257795748254
# iteration is 98
# likelyHood is -43.129985973623256
# iteration is 99
# likelyHood is -42.93205814401947
# iteration is 100
# likelyHood is -42.73865267852987
# iteration is 101
# likelyHood is -42.549633064638
# iteration is 102
# likelyHood is -42.364867833745656
# iteration is 103
# likelyHood is -42.18423033956806
# iteration is 104
# likelyHood is -42.00759854791594
# iteration is 105
# likelyHood is -41.83485483719494
# iteration is 106
# likelyHood is -41.66588580899607
# iteration is 107
# likelyHood is -41.50058210819022
# iteration is 108
# likelyHood is -41.33883825197926
# iteration is 109
# likelyHood is -41.180552467388985
# iteration is 110
# likelyHood is -41.02562653672414
# iteration is 111
# likelyHood is -40.87396565053508
# iteration is 112
# likelyHood is -40.72547826767526
# iteration is 113
# likelyHood is -40.580075982054076
# iteration is 114
# likelyHood is -40.43767339571659
# iteration is 115
# likelyHood is -40.29818799790188
# iteration is 116
# likelyHood is -40.16154004975668
# iteration is 117
# likelyHood is -40.02765247439802
# iteration is 118
# likelyHood is -39.89645075203963
# iteration is 119
# likelyHood is -39.767862819913184
# iteration is 120
# likelyHood is -39.641818976731514
# iteration is 121
# likelyHood is -39.518251791457345
# iteration is 122
# likelyHood is -39.39709601615396
# iteration is 123
# likelyHood is -39.278288502708094
# iteration is 124
# likelyHood is -39.161768123227624
# iteration is 125
# likelyHood is -39.047475693927765
# iteration is 126
# likelyHood is -38.93535390233098
# iteration is 127
# likelyHood is -38.825347237615
# iteration is 128
# likelyHood is -38.717401923953254
# iteration is 129
# likelyHood is -38.61146585670102
# iteration is 130
# likelyHood is -38.50748854128777
# iteration is 131
# likelyHood is -38.40542103468578
# iteration is 132
# likelyHood is -38.30521588932987
# iteration is 133
# likelyHood is -38.20682709937235
# iteration is 134
# likelyHood is -38.110210049161594
# iteration is 135
# likelyHood is -38.01532146384004
# iteration is 136
# likelyHood is -37.922119361962245
# iteration is 137
# likelyHood is -37.83056301003888
# iteration is 138
# likelyHood is -37.74061287891824
# iteration is 139
# likelyHood is -37.6522306019203
# iteration is 140
# likelyHood is -37.56537893464383
# iteration is 141
# likelyHood is -37.48002171637082
# iteration is 142
# likelyHood is -37.396123832995634
# iteration is 143
# likelyHood is -37.31365118141127
# iteration is 144
# likelyHood is -37.23257063528775
# iteration is 145
# likelyHood is -37.15285001218058
# iteration is 146
# likelyHood is -37.07445804191134
# iteration is 147
# likelyHood is -36.99736433616439
# iteration is 148
# likelyHood is -36.9215393592469
# iteration is 149
# likelyHood is -36.84695439996188
# iteration is 150
# likelyHood is -36.77358154454635
# iteration is 151
# likelyHood is -36.70139365062901
# iteration is 152
# likelyHood is -36.63036432216395
# iteration is 153
# likelyHood is -36.56046788529939
# iteration is 154
# likelyHood is -36.491679365141756
# iteration is 155
# likelyHood is -36.42397446337763
# iteration is 156
# likelyHood is -36.35732953671803
# iteration is 157
# likelyHood is -36.29172157613063
# iteration is 158
# likelyHood is -36.22712818682772
# iteration is 159
# likelyHood is -36.163527568978594
# iteration is 160
# likelyHood is -36.10089849911701
# iteration is 161
# likelyHood is -36.03922031221536
# iteration is 162
# likelyHood is -35.97847288439853
# iteration is 163
# likelyHood is -35.91863661627183
# iteration is 164
# likelyHood is -35.85969241683842
# iteration is 165
# likelyHood is -35.80162168798248
# iteration is 166
# likelyHood is -35.74440630949599
# iteration is 167
# likelyHood is -35.68802862462753
# iteration is 168
# likelyHood is -35.63247142613236
# iteration is 169
# likelyHood is -35.57771794280467
# iteration is 170
# likelyHood is -35.5237518264728
# iteration is 171
# likelyHood is -35.47055713943941
# iteration is 172
# likelyHood is -35.418118342350006
# iteration is 173
# likelyHood is -35.36642028247276
# iteration is 174
# likelyHood is -35.31544818237407
# iteration is 175
# likelyHood is -35.265187628975106
# iteration is 176
# likelyHood is -35.21562456297441
# iteration is 177
# likelyHood is -35.16674526862303
# iteration is 178
# likelyHood is -35.118536363839
# iteration is 179
# likelyHood is -35.070984790648176
# iteration is 180
# likelyHood is -35.024077805939655
# iteration is 181
# likelyHood is -34.977802972523826
# iteration is 182
# likelyHood is -34.93214815048182
# iteration is 183
# likelyHood is -34.88710148879605
# iteration is 184
# likelyHood is -34.84265141725123
# iteration is 185
# likelyHood is -34.798786638596
# iteration is 186
# likelyHood is -34.755496120955684
# iteration is 187
# likelyHood is -34.71276909048751
# iteration is 188
# likelyHood is -34.67059502426903
# iteration is 189
# likelyHood is -34.628963643411566
# iteration is 190
# likelyHood is -34.58786490639083
# iteration is 191
# likelyHood is -34.547289002586915
# iteration is 192
# likelyHood is -34.5072263460258
# iteration is 193
# likelyHood is -34.467667569316255
# iteration is 194
# likelyHood is -34.428603517774086
# iteration is 195
# likelyHood is -34.390025243728225
# iteration is 196
# likelyHood is -34.35192400100158
# iteration is 197
# likelyHood is -34.31429123956109
# iteration is 198
# likelyHood is -34.277118600330745
# iteration is 199
# likelyHood is -34.24039791016225
# iteration is 200
# likelyHood is -34.20412117695784
# iteration is 201
# likelyHood is -34.168280584939964
# iteration is 202
# likelyHood is -34.13286849006308
# iteration is 203
# likelyHood is -34.09787741556235
# iteration is 204
# likelyHood is -34.06330004763505
# iteration is 205
# likelyHood is -34.02912923125005
# iteration is 206
# likelyHood is -33.99535796608084
# col_0  0.0  1.0
# row_0
# 0       29    3
# 1        1    1
# iteration is 0
# likelyHood is -128.916033850503
# iteration is 1
# likelyHood is -125.54220961471434
# iteration is 2
# likelyHood is -122.27798663055555
# iteration is 3
# likelyHood is -119.12287935751162
# iteration is 4
# likelyHood is -116.07611401293501
# iteration is 5
# likelyHood is -113.13663371691834
# iteration is 6
# likelyHood is -110.30310785694832
# iteration is 7
# likelyHood is -107.57394544249074
# iteration is 8
# likelyHood is -104.94731206640375
# iteration is 9
# likelyHood is -102.42114995944814
# iteration is 10
# likelyHood is -99.99320052617249
# iteration is 11
# likelyHood is -97.66102869139574
# iteration is 12
# likelyHood is -95.42204836821189
# iteration is 13
# likelyHood is -93.27354837837156
# iteration is 14
# likelyHood is -91.2127182079522
# iteration is 15
# likelyHood is -89.23667305708122
# iteration is 16
# likelyHood is -87.34247773299064
# iteration is 17
# likelyHood is -85.5271690321583
# iteration is 18
# likelyHood is -83.7877763524316
# iteration is 19
# likelyHood is -82.12134036435309
# iteration is 20
# likelyHood is -80.52492964889582
# iteration is 21
# likelyHood is -78.99565527468641
# iteration is 22
# likelyHood is -77.53068334116435
# iteration is 23
# likelyHood is -76.12724555559096
# iteration is 24
# likelyHood is -74.78264794259879
# iteration is 25
# likelyHood is -73.49427780655901
# iteration is 26
# likelyHood is -72.2596090810277
# iteration is 27
# likelyHood is -71.07620620741639
# iteration is 28
# likelyHood is -69.94172668816968
# iteration is 29
# likelyHood is -68.85392245929302
# iteration is 30
# likelyHood is -67.81064022401594
# iteration is 31
# likelyHood is -66.80982088448086
# iteration is 32
# likelyHood is -65.8494982022144
# iteration is 33
# likelyHood is -64.92779681121459
# iteration is 34
# likelyHood is -64.04292970008419
# iteration is 35
# likelyHood is -63.19319527195223
# iteration is 36
# likelyHood is -62.37697408305055
# iteration is 37
# likelyHood is -61.592725352782686
# iteration is 38
# likelyHood is -60.83898332991447
# iteration is 39
# likelyHood is -60.1143535910923
# iteration is 40
# likelyHood is -59.417509339214
# iteration is 41
# likelyHood is -58.74718776023093
# iteration is 42
# likelyHood is -58.10218648777486
# iteration is 43
# likelyHood is -57.481360215668644
# iteration is 44
# likelyHood is -56.88361748903365
# iteration is 45
# likelyHood is -56.307917695545065
# iteration is 46
# likelyHood is -55.75326826963184
# iteration is 47
# likelyHood is -55.21872211431559
# iteration is 48
# likelyHood is -54.70337523816039
# iteration is 49
# likelyHood is -54.20636459866095
# iteration is 50
# likelyHood is -53.72686613847337
# iteration is 51
# likelyHood is -53.26409299726796
# iteration is 52
# likelyHood is -52.817293879650535
# iteration is 53
# likelyHood is -52.38575155850182
# iteration is 54
# likelyHood is -51.968781493079526
# iteration is 55
# likelyHood is -51.56573054214722
# iteration is 56
# likelyHood is -51.175975754030766
# iteration is 57
# likelyHood is -50.798923217641644
# iteration is 58
# likelyHood is -50.43400696094329
# iteration is 59
# likelyHood is -50.08068788588194
# iteration is 60
# likelyHood is -49.738452731304854
# iteration is 61
# likelyHood is -49.40681305772178
# iteration is 62
# likelyHood is -49.085304249844654
# iteration is 63
# likelyHood is -48.773484534616635
# iteration is 64
# likelyHood is -48.470934013889085
# iteration is 65
# likelyHood is -48.177253712026925
# iteration is 66
# likelyHood is -47.89206463954033
# iteration is 67
# likelyHood is -47.615006874381244
# iteration is 68
# likelyHood is -47.34573866285361
# iteration is 69
# likelyHood is -47.08393554219646
# iteration is 70
# likelyHood is -46.82928948686566
# iteration is 71
# likelyHood is -46.58150808038544
# iteration is 72
# likelyHood is -46.34031371441456
# iteration is 73
# likelyHood is -46.1054428163896
# iteration is 74
# likelyHood is -45.87664510680589
# iteration is 75
# likelyHood is -45.6536828868839
# iteration is 76
# likelyHood is -45.43633035706745
# iteration is 77
# likelyHood is -45.22437296651379
# iteration is 78
# likelyHood is -45.01760679347895
# iteration is 79
# likelyHood is -44.81583795626961
# iteration is 80
# likelyHood is -44.618882054235705
# iteration is 81
# likelyHood is -44.42656363811026
# iteration is 82
# likelyHood is -44.2387157088661
# iteration is 83
# likelyHood is -44.055179244151354
# iteration is 84
# likelyHood is -43.875802751281846
# iteration is 85
# likelyHood is -43.70044184571239
# iteration is 86
# likelyHood is -43.52895885386621
# iteration is 87
# likelyHood is -43.36122243918604
# iteration is 88
# likelyHood is -43.19710725026017
# iteration is 89
# likelyHood is -43.036493589886405
# iteration is 90
# likelyHood is -42.8792671039531
# iteration is 91
# likelyHood is -42.72531848904199
# iteration is 92
# likelyHood is -42.57454321768821
# iteration is 93
# likelyHood is -42.4268412802723
# iteration is 94
# likelyHood is -42.28211694255613
# iteration is 95
# likelyHood is -42.14027851791957
# iteration is 96
# likelyHood is -42.001238153398134
# iteration is 97
# likelyHood is -41.86491162866637
# iteration is 98
# likelyHood is -41.73121816715733
# iteration is 99
# likelyHood is -41.600080258552005
# iteration is 100
# likelyHood is -41.47142349191739
# iteration is 101
# likelyHood is -41.34517639881203
# iteration is 102
# likelyHood is -41.22127030572144
# iteration is 103
# likelyHood is -41.0996391952226
# iteration is 104
# likelyHood is -40.98021957531594
# iteration is 105
# likelyHood is -40.862950356397945
# iteration is 106
# likelyHood is -40.74777273538195
# iteration is 107
# likelyHood is -40.63463008650682
# iteration is 108
# likelyHood is -40.52346785840284
# iteration is 109
# likelyHood is -40.41423347701398
# iteration is 110
# likelyHood is -40.306876254000386
# iteration is 111
# likelyHood is -40.201347300272545
# iteration is 112
# likelyHood is -40.097599444329994
# iteration is 113
# likelyHood is -39.995587155100985
# iteration is 114
# likelyHood is -39.89526646899855
# iteration is 115
# likelyHood is -39.79659492092954
# iteration is 116
# likelyHood is -39.69953147900936
# iteration is 117
# likelyHood is -39.60403648275223
# iteration is 118
# likelyHood is -39.510071584523594
# iteration is 119
# likelyHood is -39.41759969405385
# iteration is 120
# likelyHood is -39.32658492582723
# iteration is 121
# likelyHood is -39.23699254917199
# iteration is 122
# likelyHood is -39.14878894088975
# iteration is 123
# likelyHood is -39.06194154027221
# iteration is 124
# likelyHood is -38.97641880636373
# iteration is 125
# likelyHood is -38.892190177338684
# iteration is 126
# likelyHood is -38.80922603186878
# iteration is 127
# likelyHood is -38.727497652366715
# iteration is 128
# likelyHood is -38.64697718999706
# iteration is 129
# likelyHood is -38.56763763135436
# iteration is 130
# likelyHood is -38.48945276671442
# iteration is 131
# likelyHood is -38.412397159769924
# iteration is 132
# likelyHood is -38.336446118768194
# iteration is 133
# likelyHood is -38.26157566897419
# iteration is 134
# likelyHood is -38.187762526385434
# iteration is 135
# likelyHood is -38.114984072631664
# iteration is 136
# likelyHood is -38.043218330995074
# iteration is 137
# likelyHood is -37.972443943491974
# iteration is 138
# likelyHood is -37.902640148959065
# iteration is 139
# likelyHood is -37.833786762092
# iteration is 140
# likelyHood is -37.76586415338719
# iteration is 141
# likelyHood is -37.6988532299393
# iteration is 142
# likelyHood is -37.63273541705189
# iteration is 143
# likelyHood is -37.567492640619086
# iteration is 144
# likelyHood is -37.50310731024009
# iteration is 145
# likelyHood is -37.43956230303005
# iteration is 146
# likelyHood is -37.3768409480925
# iteration is 147
# likelyHood is -37.31492701162164
# iteration is 148
# likelyHood is -37.25380468260317
# iteration is 149
# likelyHood is -37.19345855908553
# iteration is 150
# likelyHood is -37.13387363499399
# iteration is 151
# likelyHood is -37.075035287461866
# iteration is 152
# likelyHood is -37.01692926465506
# iteration is 153
# likelyHood is -36.959541674066074
# iteration is 154
# likelyHood is -36.90285897125692
# iteration is 155
# likelyHood is -36.846867949029566
# iteration is 156
# likelyHood is -36.79155572700501
# iteration is 157
# likelyHood is -36.73690974159212
# iteration is 158
# likelyHood is -36.68291773632943
# iteration is 159
# likelyHood is -36.629567752582545
# iteration is 160
# likelyHood is -36.57684812058278
# iteration is 161
# likelyHood is -36.524747450790606
# iteration is 162
# likelyHood is -36.47325462557104
# iteration is 163
# likelyHood is -36.42235879116721
# iteration is 164
# likelyHood is -36.37204934995932
# iteration is 165
# likelyHood is -36.322315952996824
# iteration is 166
# likelyHood is -36.27314849279274
# iteration is 167
# likelyHood is -36.22453709636896
# iteration is 168
# likelyHood is -36.17647211854203
# iteration is 169
# likelyHood is -36.128944135439944
# iteration is 170
# likelyHood is -36.08194393824006
# iteration is 171
# likelyHood is -36.03546252711955
# iteration is 172
# likelyHood is -35.98949110540981
# iteration is 173
# likelyHood is -35.94402107394644
# iteration is 174
# likelyHood is -35.899044025607395
# iteration is 175
# likelyHood is -35.85455174003187
# iteration is 176
# likelyHood is -35.810536178512365
# iteration is 177
# likelyHood is -35.766989479054
# iteration is 178
# likelyHood is -35.723903951594075
# iteration is 179
# likelyHood is -35.681272073375915
# iteration is 180
# likelyHood is -35.63908648447116
# iteration is 181
# likelyHood is -35.597339983444904
# iteration is 182
# likelyHood is -35.5560255231583
# iteration is 183
# likelyHood is -35.51513620670335
# iteration is 184
# likelyHood is -35.474665283465534
# iteration is 185
# likelyHood is -35.434606145308685
# iteration is 186
# likelyHood is -35.394952322878495
# iteration is 187
# likelyHood is -35.355697482019934
# iteration is 188
# likelyHood is -35.31683542030434
# iteration is 189
# likelyHood is -35.278360063662724
# iteration is 190
# likelyHood is -35.24026546312087
# iteration is 191
# likelyHood is -35.20254579163324
# iteration is 192
# likelyHood is -35.16519534101169
# iteration is 193
# likelyHood is -35.12820851894612
# iteration is 194
# likelyHood is -35.09157984611333
# iteration is 195
# likelyHood is -35.055303953371684
# iteration is 196
# likelyHood is -35.019375579037884
# iteration is 197
# likelyHood is -34.983789566243814
# iteration is 198
# likelyHood is -34.94854086036996
# iteration is 199
# likelyHood is -34.91362450655341
# col_0  0.0  1.0
# row_0
# 0        0    1
# 1        4   29
# iteration is 0
# likelyHood is -1399.810144789315
# iteration is 1
# likelyHood is -1122.1796481376564
# iteration is 2
# likelyHood is -899.4823516311668
# iteration is 3
# likelyHood is -727.7275872404041
# iteration is 4
# likelyHood is -598.1493870267193
# iteration is 5
# likelyHood is -500.81003292863187
# iteration is 6
# likelyHood is -427.10428227194024
# iteration is 7
# likelyHood is -370.51684290918075
# iteration is 8
# likelyHood is -326.3878847822245
# iteration is 9
# likelyHood is -291.43352942823594
# iteration is 10
# likelyHood is -263.33003410441694
# iteration is 11
# likelyHood is -240.41523175497628
# iteration is 12
# likelyHood is -221.48520264110604
# iteration is 13
# likelyHood is -205.65679475921968
# iteration is 14
# likelyHood is -192.27397836002484
# iteration is 15
# likelyHood is -180.84337352596745
# iteration is 16
# likelyHood is -170.989389585479
# iteration is 17
# likelyHood is -162.4226947625391
# iteration is 18
# likelyHood is -154.91783552840786
# iteration is 19
# likelyHood is -148.29719182399
# iteration is 20
# likelyHood is -142.4193573286531
# iteration is 21
# likelyHood is -137.17063736350963
# iteration is 22
# likelyHood is -132.4587633769958
# iteration is 23
# likelyHood is -128.20819830525744
# iteration is 24
# likelyHood is -124.35659477890664
# iteration is 25
# likelyHood is -120.85209689412478
# iteration is 26
# likelyHood is -117.65126521349401
# iteration is 27
# likelyHood is -114.71746659016323
# iteration is 28
# likelyHood is -112.01961388145652
# iteration is 29
# likelyHood is -109.53117139666844
# iteration is 30
# likelyHood is -107.2293639055776
# iteration is 31
# likelyHood is -105.09454287100087
# iteration is 32
# likelyHood is -103.10967507757859
# iteration is 33
# likelyHood is -101.25992726413138
# iteration is 34
# likelyHood is -99.53232660089137
# iteration is 35
# likelyHood is -97.9154814974249
# iteration is 36
# likelyHood is -96.39935071455166
# iteration is 37
# likelyHood is -94.97505139207472
# iteration is 38
# likelyHood is -93.6346986148977
# iteration is 39
# likelyHood is -92.37127068322518
# iteration is 40
# likelyHood is -91.17849544473164
# iteration is 41
# likelyHood is -90.05075397363889
# iteration is 42
# likelyHood is -88.98299860695187
# iteration is 43
# likelyHood is -87.97068291899733
# iteration is 44
# likelyHood is -87.00970166728055
# iteration is 45
# likelyHood is -86.09633910233592
# iteration is 46
# likelyHood is -85.22722432198077
# iteration is 47
# likelyHood is -84.39929258176583
# iteration is 48
# likelyHood is -83.60975166036032
# iteration is 49
# likelyHood is -82.85605253036636
# iteration is 50
# likelyHood is -82.13586370879759
# iteration is 51
# likelyHood is -81.44704876277481
# iteration is 52
# likelyHood is -80.78764652931072
# iteration is 53
# likelyHood is -80.15585367683386
# iteration is 54
# likelyHood is -79.55000929308518
# iteration is 55
# likelyHood is -78.96858123143768
# iteration is 56
# likelyHood is -78.41015398723809
# iteration is 57
# likelyHood is -77.87341790892073
# iteration is 58
# likelyHood is -77.3571595764761
# iteration is 59
# likelyHood is -76.86025320333795
# iteration is 60
# likelyHood is -76.38165293758799
# iteration is 61
# likelyHood is -75.92038595521761
# iteration is 62
# likelyHood is -75.47554625249762
# iteration is 63
# likelyHood is -75.04628905670592
# iteration is 64
# likelyHood is -74.631825784918
# iteration is 65
# likelyHood is -74.23141948950067
# iteration is 66
# likelyHood is -73.84438073665117
# iteration is 67
# likelyHood is -73.47006387094653
# iteration is 68
# likelyHood is -73.1078636245957
# iteration is 69
# likelyHood is -72.75721203503873
# iteration is 70
# likelyHood is -72.41757563883526
# iteration is 71
# likelyHood is -72.08845291352785
# iteration is 72
# likelyHood is -71.76937194240755
# iteration is 73
# likelyHood is -71.45988827996925
# iteration is 74
# likelyHood is -71.15958299831006
# iteration is 75
# likelyHood is -70.86806089691977
# iteration is 76
# likelyHood is -70.58494886021498
# iteration is 77
# likelyHood is -70.30989434884901
# iteration is 78
# likelyHood is -70.0425640123215
# iteration is 79
# likelyHood is -69.78264241171023
# iteration is 80
# likelyHood is -69.52983084250675
# iteration is 81
# likelyHood is -69.28384624856452
# iteration is 82
# likelyHood is -69.04442021907128
# iteration is 83
# likelyHood is -68.81129806126827
# iteration is 84
# likelyHood is -68.58423794235286
# iteration is 85
# likelyHood is -68.36301009464495
# iteration is 86
# likelyHood is -68.14739607865994
# iteration is 87
# likelyHood is -67.93718809925129
# iteration is 88
# likelyHood is -67.73218837043069
# iteration is 89
# likelyHood is -67.53220852488879
# iteration is 90
# likelyHood is -67.33706906460473
# iteration is 91
# likelyHood is -67.14659884925618
# iteration is 92
# likelyHood is -66.96063461944786
# iteration is 93
# likelyHood is -66.77902055202858
# iteration is 94
# likelyHood is -66.60160784502042
# iteration is 95
# likelyHood is -66.4282543298903
# iteration is 96
# likelyHood is -66.2588241090934
# iteration is 97
# likelyHood is -66.093187216996
# iteration is 98
# likelyHood is -65.9312193024428
# iteration is 99
# likelyHood is -65.77280133137832
# iteration is 100
# likelyHood is -65.61781930806843
# iteration is 101
# likelyHood is -65.46616401357873
# iteration is 102
# likelyHood is -65.31773076028705
# iteration is 103
# likelyHood is -65.17241916129231
# iteration is 104
# likelyHood is -65.0301329136853
# iteration is 105
# likelyHood is -64.89077959471862
# iteration is 106
# likelyHood is -64.75427046999329
# iteration is 107
# likelyHood is -64.6205203128482
# iteration is 108
# likelyHood is -64.48944723419572
# iteration is 109
# likelyHood is -64.36097252211175
# iteration is 110
# likelyHood is -64.23502049053357
# iteration is 111
# likelyHood is -64.11151833647254
# iteration is 112
# likelyHood is -63.99039600518639
# iteration is 113
# likelyHood is -63.871586062805136
# iteration is 114
# likelyHood is -63.75502357593111
# iteration is 115
# likelyHood is -63.64064599777708
# iteration is 116
# likelyHood is -63.52839306043157
# iteration is 117
# likelyHood is -63.41820667287179
# iteration is 118
# likelyHood is -63.3100308243724
# iteration is 119
# likelyHood is -63.203811492980094
# iteration is 120
# likelyHood is -63.09949655874701
# iteration is 121
# likelyHood is -62.997035721441826
# iteration is 122
# likelyHood is -62.8963804224664
# iteration is 123
# likelyHood is -62.79748377073632
# iteration is 124
# likelyHood is -62.700300472290564
# iteration is 125
# likelyHood is -62.60478676341259
# iteration is 126
# likelyHood is -62.51090034706533
# iteration is 127
# likelyHood is -62.41860033244744
# iteration is 128
# likelyHood is -62.32784717749548
# iteration is 129
# likelyHood is -62.23860263416651
# iteration is 130
# likelyHood is -62.15082969634599
# iteration is 131
# likelyHood is -62.06449255023636
# iteration is 132
# likelyHood is -61.97955652709016
# iteration is 133
# likelyHood is -61.89598805815868
# iteration is 134
# likelyHood is -61.81375463173798
# iteration is 135
# likelyHood is -61.73282475220077
# iteration is 136
# likelyHood is -61.65316790090394
# iteration is 137
# likelyHood is -61.57475449887882
# iteration is 138
# likelyHood is -61.497555871205606
# iteration is 139
# likelyHood is -61.42154421298628
# iteration is 140
# likelyHood is -61.346692556834135
# iteration is 141
# likelyHood is -61.27297474180005
# iteration is 142
# likelyHood is -61.20036538366478
# iteration is 143
# likelyHood is -61.12883984652471
# iteration is 144
# likelyHood is -61.058374215610506
# iteration is 145
# likelyHood is -60.988945271272094
# iteration is 146
# likelyHood is -60.9205304640773
# iteration is 147
# likelyHood is -60.853107890964786
# iteration is 148
# likelyHood is -60.7866562724029
# iteration is 149
# likelyHood is -60.72115493050388
# iteration is 150
# likelyHood is -60.65658376804807
# iteration is 151
# likelyHood is -60.59292324837429
# iteration is 152
# likelyHood is -60.53015437609448
# iteration is 153
# likelyHood is -60.46825867859625
# iteration is 154
# likelyHood is -60.407218188291985
# iteration is 155
# likelyHood is -60.347015425583265
# col_0  0.0  1.0
# row_0
# 0      258    4
# iteration is 0
# likelyHood is -894.8788902900823
# iteration is 1
# likelyHood is -704.827228864707
# iteration is 2
# likelyHood is -565.088294214387
# iteration is 3
# likelyHood is -464.4828040827269
# iteration is 4
# likelyHood is -391.82849796411745
# iteration is 5
# likelyHood is -338.4494973503955
# iteration is 6
# likelyHood is -298.3107674823981
# iteration is 7
# likelyHood is -267.37752385513954
# iteration is 8
# likelyHood is -242.9731000480435
# iteration is 9
# likelyHood is -223.30712034058314
# iteration is 10
# likelyHood is -207.1617093416298
# iteration is 11
# likelyHood is -193.69080756601457
# iteration is 12
# likelyHood is -182.2933385992195
# iteration is 13
# likelyHood is -172.5327673437567
# iteration is 14
# likelyHood is -164.08543266511327
# iteration is 15
# likelyHood is -156.7067714575222
# iteration is 16
# likelyHood is -150.2087949675368
# iteration is 17
# likelyHood is -144.4447588209103
# iteration is 18
# likelyHood is -139.2985192217941
# iteration is 19
# likelyHood is -134.67700200785563
# iteration is 20
# likelyHood is -130.5047796902846
# iteration is 21
# likelyHood is -126.72010259617623
# iteration is 22
# likelyHood is -123.27195064967891
# iteration is 23
# likelyHood is -120.11781323956697
# iteration is 24
# likelyHood is -117.22199632798014
# iteration is 25
# likelyHood is -114.55431668717496
# iteration is 26
# likelyHood is -112.08908404573022
# iteration is 27
# likelyHood is -109.80429989980799
# iteration is 28
# likelyHood is -107.68102116644863
# iteration is 29
# likelyHood is -105.70285052763576
# iteration is 30
# likelyHood is -103.85552506358314
# iteration is 31
# likelyHood is -102.12658181110487
# iteration is 32
# likelyHood is -100.50508402020459
# iteration is 33
# likelyHood is -98.98139567202887
# iteration is 34
# likelyHood is -97.54699464507341
# iteration is 35
# likelyHood is -96.19431703996636
# iteration is 36
# likelyHood is -94.9166267838359
# iteration is 37
# likelyHood is -93.70790586706362
# iteration is 38
# likelyHood is -92.56276151450527
# iteration is 39
# likelyHood is -91.47634733015602
# iteration is 40
# likelyHood is -90.44429603020644
# iteration is 41
# likelyHood is -89.46266183253748
# iteration is 42
# likelyHood is -88.52787092936568
# iteration is 43
# likelyHood is -87.63667875531581
# iteration is 44
# likelyHood is -86.7861329918275
# iteration is 45
# likelyHood is -85.97354143282494
# iteration is 46
# likelyHood is -85.19644398545667
# iteration is 47
# likelyHood is -84.45258820071882
# iteration is 48
# likelyHood is -83.73990782761017
# iteration is 49
# likelyHood is -83.0565039655235
# iteration is 50
# likelyHood is -82.40062845636136
# iteration is 51
# likelyHood is -81.7706692130917
# iteration is 52
# likelyHood is -81.16513722732056
# iteration is 53
# likelyHood is -80.58265503667953
# iteration is 54
# likelyHood is -80.02194646479583
# iteration is 55
# likelyHood is -79.48182747344688
# iteration is 56
# likelyHood is -78.96119798909966
# iteration is 57
# likelyHood is -78.45903458511908
# iteration is 58
# likelyHood is -77.9743839171127
# iteration is 59
# likelyHood is -77.50635682262379
# iteration is 60
# likelyHood is -77.05412300810153
# iteration is 61
# likelyHood is -76.61690625609145
# iteration is 62
# likelyHood is -76.19398009417193
# iteration is 63
# likelyHood is -75.78466387452747
# iteration is 64
# likelyHood is -75.38831921939956
# iteration is 65
# likelyHood is -75.00434679313678
# iteration is 66
# likelyHood is -74.63218336629441
# iteration is 67
# likelyHood is -74.27129914135371
# iteration is 68
# likelyHood is -73.9211953131886
# iteration is 69
# likelyHood is -73.58140184052618
# iteration is 70
# likelyHood is -73.25147540734265
# iteration is 71
# likelyHood is -72.93099755552038
# iteration is 72
# likelyHood is -72.61957297215217
# iteration is 73
# likelyHood is -72.31682791670421
# iteration is 74
# likelyHood is -72.02240877484834
# iteration is 75
# likelyHood is -71.73598072717512
# iteration is 76
# likelyHood is -71.45722652224507
# iteration is 77
# likelyHood is -71.18584534452829
# iteration is 78
# likelyHood is -70.92155176875234
# iteration is 79
# likelyHood is -70.66407479303717
# iteration is 80
# likelyHood is -70.41315694395384
# iteration is 81
# likelyHood is -70.16855344732966
# iteration is 82
# likelyHood is -69.93003145921404
# iteration is 83
# likelyHood is -69.69736935196407
# iteration is 84
# likelyHood is -69.47035605088789
# iteration is 85
# likelyHood is -69.24879041730685
# iteration is 86
# likelyHood is -69.03248067428734
# iteration is 87
# likelyHood is -68.82124387163529
# iteration is 88
# likelyHood is -68.61490538705145
# iteration is 89
# likelyHood is -68.41329846063088
# iteration is 90
# likelyHood is -68.2162637601294
# iteration is 91
# likelyHood is -68.02364897465405
# iteration is 92
# likelyHood is -67.83530843463294
# iteration is 93
# likelyHood is -67.65110275610263
# iteration is 94
# likelyHood is -67.47089850752057
# iteration is 95
# likelyHood is -67.29456789745534
# iteration is 96
# likelyHood is -67.12198848164881
# iteration is 97
# likelyHood is -66.95304288806479
# iteration is 98
# likelyHood is -66.78761855864889
# iteration is 99
# likelyHood is -66.62560750663145
# iteration is 100
# likelyHood is -66.46690608829604
# iteration is 101
# likelyHood is -66.31141478821668
# iteration is 102
# likelyHood is -66.15903801705203
# iteration is 103
# likelyHood is -66.00968392104876
# iteration is 104
# likelyHood is -65.86326420247154
# iteration is 105
# likelyHood is -65.71969395024207
# iteration is 106
# likelyHood is -65.57889148011364
# iteration is 107
# likelyHood is -65.44077818376644
# iteration is 108
# likelyHood is -65.30527838624857
# iteration is 109
# likelyHood is -65.17231921123135
# iteration is 110
# likelyHood is -65.04183045358566
# iteration is 111
# likelyHood is -64.91374445882182
# iteration is 112
# likelyHood is -64.7879960089657
# iteration is 113
# likelyHood is -64.6645222144779
# iteration is 114
# likelyHood is -64.543262411843
# iteration is 115
# likelyHood is -64.4241580664927
# iteration is 116
# likelyHood is -64.3071526807364
# iteration is 117
# likelyHood is -64.1921917064054
# iteration is 118
# likelyHood is -64.07922246193283
# iteration is 119
# likelyHood is -63.96819405360775
# iteration is 120
# likelyHood is -63.85905730076271
# iteration is 121
# likelyHood is -63.7517646646685
# iteration is 122
# likelyHood is -63.64627018092414
# iteration is 123
# likelyHood is -63.54252939514383
# iteration is 124
# likelyHood is -63.44049930175633
# iteration is 125
# likelyHood is -63.340138285741915
# iteration is 126
# likelyHood is -63.24140606714599
# iteration is 127
# likelyHood is -63.14426364821634
# iteration is 128
# likelyHood is -63.0486732630198
# iteration is 129
# likelyHood is -62.954598329406096
# iteration is 130
# likelyHood is -62.86200340319121
# iteration is 131
# likelyHood is -62.77085413444376
# iteration is 132
# likelyHood is -62.681117225761284
# iteration is 133
# likelyHood is -62.59276039243306
# iteration is 134
# likelyHood is -62.50575232439131
# iteration is 135
# likelyHood is -62.42006264985648
# iteration is 136
# likelyHood is -62.33566190059293
# iteration is 137
# likelyHood is -62.25252147868781
# iteration is 138
# likelyHood is -62.170613624782035
# iteration is 139
# likelyHood is -62.08991138767454
# iteration is 140
# likelyHood is -62.01038859523522
# iteration is 141
# likelyHood is -61.93201982655935
# iteration is 142
# likelyHood is -61.85478038530424
# iteration is 143
# likelyHood is -61.778646274147285
# iteration is 144
# likelyHood is -61.70359417031467
# iteration is 145
# likelyHood is -61.629601402125694
# iteration is 146
# likelyHood is -61.55664592650589
# iteration is 147
# likelyHood is -61.484706307422506
# iteration is 148
# likelyHood is -61.41376169519712
# iteration is 149
# likelyHood is -61.34379180665791
# iteration is 150
# likelyHood is -61.274776906086814
# iteration is 151
# likelyHood is -61.20669778693025
# iteration is 152
# likelyHood is -61.13953575423413
# iteration is 153
# likelyHood is -61.07327260777217
# iteration is 154
# likelyHood is -61.00789062583456
# iteration is 155
# likelyHood is -60.943372549648785
# iteration is 156
# likelyHood is -60.87970156840231
# iteration is 157
# likelyHood is -60.81686130484091
# iteration is 158
# likelyHood is -60.75483580141877
# iteration is 159
# likelyHood is -60.693609506971356
# iteration is 160
# likelyHood is -60.63316726389567
# col_0  0.0  1.0
# row_0
# 1        4  258
# iteration is 0
# likelyHood is -2036.7649116404252
# iteration is 1
# likelyHood is -1470.9608384703442
# iteration is 2
# likelyHood is -1068.0953305369542
# iteration is 3
# likelyHood is -799.6765450823442
# iteration is 4
# likelyHood is -622.6850897400362
# iteration is 5
# likelyHood is -503.40016314598006
# iteration is 6
# likelyHood is -420.37387172641104
# iteration is 7
# likelyHood is -360.6196573886374
# iteration is 8
# likelyHood is -316.2307433924201
# iteration is 9
# likelyHood is -282.2938434144641
# iteration is 10
# likelyHood is -255.67961143128954
# iteration is 11
# likelyHood is -234.3413524399995
# iteration is 12
# likelyHood is -216.90370908496027
# iteration is 13
# likelyHood is -202.41766770140674
# iteration is 14
# likelyHood is -190.21181988391754
# iteration is 15
# likelyHood is -179.8000666463843
# iteration is 16
# likelyHood is -170.8229995352174
# iteration is 17
# likelyHood is -163.00978851163188
# iteration is 18
# likelyHood is -156.15283257315681
# iteration is 19
# likelyHood is -150.0905312693864
# iteration is 20
# likelyHood is -144.69533664657234
# iteration is 21
# likelyHood is -139.86531055629197
# iteration is 22
# likelyHood is -135.51805490622743
# iteration is 23
# likelyHood is -131.5862779101407
# iteration is 24
# likelyHood is -128.01450762132185
# iteration is 25
# likelyHood is -124.75662283702191
# iteration is 26
# likelyHood is -121.77397492224883
# iteration is 27
# likelyHood is -119.03394267862517
# iteration is 28
# likelyHood is -116.50880858379861
# iteration is 29
# likelyHood is -114.17487632990422
# iteration is 30
# likelyHood is -112.01177151939484
# iteration is 31
# likelyHood is -110.00188279953844
# iteration is 32
# likelyHood is -108.12991170106915
# iteration is 33
# likelyHood is -106.38250736213162
# iteration is 34
# likelyHood is -104.74796808651634
# iteration is 35
# likelyHood is -103.21599593195486
# iteration is 36
# likelyHood is -101.7774936817505
# iteration is 37
# likelyHood is -100.42439592237835
# iteration is 38
# likelyHood is -99.14952774309569
# iteration is 39
# likelyHood is -97.94648594223247
# iteration is 40
# likelyHood is -96.80953867738936
# iteration is 41
# likelyHood is -95.73354031219932
# iteration is 42
# likelyHood is -94.71385884842036
# iteration is 43
# likelyHood is -93.74631383162927
# iteration is 44
# likelyHood is -92.82712301345956
# iteration is 45
# likelyHood is -91.95285636704267
# iteration is 46
# likelyHood is -91.12039630307329
# iteration is 47
# likelyHood is -90.3269031354463
# iteration is 48
# likelyHood is -89.569785008209
# iteration is 49
# likelyHood is -88.84667162770265
# iteration is 50
# likelyHood is -88.15539125156005
# iteration is 51
# likelyHood is -87.49395047448684
# iteration is 52
# likelyHood is -86.86051642340796
# iteration is 53
# likelyHood is -86.25340103455378
# iteration is 54
# likelyHood is -85.67104713482372
# iteration is 55
# likelyHood is -85.11201609119449
# iteration is 56
# likelyHood is -84.57497682655433
# iteration is 57
# likelyHood is -84.05869602935694
# iteration is 58
# likelyHood is -83.56202940890743
# iteration is 59
# likelyHood is -83.08391386869495
# iteration is 60
# likelyHood is -82.62336048762025
# iteration is 61
# likelyHood is -82.17944821378435
# iteration is 62
# likelyHood is -81.75131818811211
# iteration is 63
# likelyHood is -81.33816862584861
# iteration is 64
# likelyHood is -80.93925019319437
# iteration is 65
# likelyHood is -80.55386182425123
# iteration is 66
# likelyHood is -80.18134693027122
# iteration is 67
# likelyHood is -79.82108995906971
# iteration is 68
# likelyHood is -79.47251326754548
# iteration is 69
# likelyHood is -79.135074274662
# iteration is 70
# likelyHood is -78.80826286605568
# iteration is 71
# likelyHood is -78.49159902477732
# iteration is 72
# likelyHood is -78.18463066557146
# iteration is 73
# likelyHood is -77.88693165263588
# iteration is 74
# likelyHood is -77.5980999830286
# iteration is 75
# likelyHood is -77.31775611983534
# iteration is 76
# likelyHood is -77.04554146092906
# iteration is 77
# likelyHood is -76.78111693065718
# iteration is 78
# likelyHood is -76.52416168312331
# iteration is 79
# likelyHood is -76.2743719069152
# iteration is 80
# likelyHood is -76.03145972215312
# iteration is 81
# likelyHood is -75.79515216167576
# iteration is 82
# likelyHood is -75.5651902289843
# iteration is 83
# likelyHood is -75.34132802630185
# iteration is 84
# likelyHood is -75.12333194674885
# iteration is 85
# likelyHood is -74.91097992521742
# iteration is 86
# likelyHood is -74.7040607430413
# iteration is 87
# likelyHood is -74.50237338201984
# iteration is 88
# likelyHood is -74.30572642376917
# iteration is 89
# likelyHood is -74.11393749074331
# iteration is 90
# likelyHood is -73.92683272560159
# iteration is 91
# likelyHood is -73.74424630589667
# iteration is 92
# likelyHood is -73.56601999132889
# iteration is 93
# likelyHood is -73.39200270105215
# iteration is 94
# likelyHood is -73.22205011873895
# iteration is 95
# likelyHood is -73.05602432330642
# iteration is 96
# likelyHood is -72.89379344338751
# iteration is 97
# likelyHood is -72.73523133378946
# iteration is 98
# likelyHood is -72.58021727233073
# iteration is 99
# likelyHood is -72.42863567558227
# iteration is 100
# likelyHood is -72.28037583215333
# iteration is 101
# likelyHood is -72.13533165228068
# iteration is 102
# likelyHood is -71.99340143257172
# iteration is 103
# likelyHood is -71.85448763484801
# iteration is 104
# likelyHood is -71.71849667811907
# iteration is 105
# likelyHood is -71.58533874278552
# iteration is 106
# likelyHood is -71.45492758625011
# iteration is 107
# likelyHood is -71.3271803691668
# iteration is 108
# likelyHood is -71.20201749162811
# iteration is 109
# likelyHood is -71.07936243863091
# iteration is 110
# likelyHood is -70.95914163422188
# iteration is 111
# likelyHood is -70.84128430375738
# iteration is 112
# likelyHood is -70.7257223437627
# iteration is 113
# likelyHood is -70.61239019890526
# iteration is 114
# likelyHood is -70.50122474563804
# iteration is 115
# likelyHood is -70.39216518209393
# iteration is 116
# likelyHood is -70.28515292384779
# iteration is 117
# likelyHood is -70.18013150518684
# iteration is 118
# likelyHood is -70.07704648555072
# iteration is 119
# likelyHood is -69.97584536083606
# iteration is 120
# likelyHood is -69.87647747927143
# iteration is 121
# likelyHood is -69.77889396159085
# iteration is 122
# likelyHood is -69.6830476252574
# iteration is 123
# likelyHood is -69.58889291249695
# iteration is 124
# likelyHood is -69.49638582192551
# iteration is 125
# likelyHood is -69.40548384355837
# iteration is 126
# likelyHood is -69.3161458970182
# iteration is 127
# likelyHood is -69.22833227274954
# iteration is 128
# likelyHood is -69.14200457608231
# iteration is 129
# likelyHood is -69.057125673979
# iteration is 130
# likelyHood is -68.97365964431968
# iteration is 131
# likelyHood is -68.89157172758742
# iteration is 132
# likelyHood is -68.810828280821
# iteration is 133
# likelyHood is -68.73139673371469
# iteration is 134
# likelyHood is -68.653245546749
# iteration is 135
# likelyHood is -68.5763441712455
# iteration is 136
# likelyHood is -68.50066301124315
# iteration is 137
# likelyHood is -68.42617338710194
# iteration is 138
# likelyHood is -68.35284750074257
# iteration is 139
# likelyHood is -68.2806584024387
# iteration is 140
# likelyHood is -68.20957995908248
# iteration is 141
# likelyHood is -68.1395868238485
# iteration is 142
# likelyHood is -68.07065440718145
# iteration is 143
# likelyHood is -68.00275884904951
# col_0  0.0  1.0
# row_0
# 0      413    4
# iteration is 0
# likelyHood is -1284.0021071075557
# iteration is 1
# likelyHood is -890.6368401976187
# iteration is 2
# likelyHood is -653.2069088100824
# iteration is 3
# likelyHood is -509.4301527105424
# iteration is 4
# likelyHood is -417.4493059606575
# iteration is 5
# likelyHood is -354.80824118465745
# iteration is 6
# likelyHood is -309.81998370157004
# iteration is 7
# likelyHood is -276.12093792163967
# iteration is 8
# likelyHood is -250.02510727371063
# iteration is 9
# likelyHood is -229.27076091251107
# iteration is 10
# likelyHood is -212.4005731389329
# iteration is 11
# likelyHood is -198.43657380229553
# iteration is 12
# likelyHood is -186.69979755281096
# iteration is 13
# likelyHood is -176.70512525006646
# iteration is 14
# likelyHood is -168.0973022554626
# iteration is 15
# likelyHood is -160.61056507716205
# iteration is 16
# likelyHood is -154.0423514835196
# iteration is 17
# likelyHood is -148.2357059057831
# iteration is 18
# likelyHood is -143.06721697466983
# iteration is 19
# likelyHood is -138.43856900273957
# iteration is 20
# likelyHood is -134.27051042550875
# iteration is 21
# likelyHood is -130.49847301358756
# iteration is 22
# likelyHood is -127.0693401183323
# iteration is 23
# likelyHood is -123.93902856686333
# iteration is 24
# likelyHood is -121.070655801402
# iteration is 25
# likelyHood is -118.43313404565443
# iteration is 26
# likelyHood is -116.00008017952435
# iteration is 27
# likelyHood is -113.74896186979743
# iteration is 28
# likelyHood is -111.66042249341295
# iteration is 29
# likelyHood is -109.7177427809043
# iteration is 30
# likelyHood is -107.90640802367561
# iteration is 31
# likelyHood is -106.21375752673627
# iteration is 32
# likelyHood is -104.62869868112902
# iteration is 33
# likelyHood is -103.14147220928987
# iteration is 34
# likelyHood is -101.74345823530189
# iteration is 35
# likelyHood is -100.4270151514636
# iteration is 36
# likelyHood is -99.1853450041572
# iteration is 37
# likelyHood is -98.01238045581349
# iteration is 38
# likelyHood is -96.90268940348473
# iteration is 39
# likelyHood is -95.85139412611082
# iteration is 40
# likelyHood is -94.8541024489768
# iteration is 41
# likelyHood is -93.90684889707333
# iteration is 42
# likelyHood is -93.00604419030618
# iteration is 43
# likelyHood is -92.14843173605843
# iteration is 44
# likelyHood is -91.33105001615304
# iteration is 45
# likelyHood is -90.55119995910711
# iteration is 46
# likelyHood is -89.80641654499445
# iteration is 47
# likelyHood is -89.09444401704229
# iteration is 48
# likelyHood is -88.41321417741828
# iteration is 49
# likelyHood is -87.7608273292214
# iteration is 50
# likelyHood is -87.13553549618644
# iteration is 51
# likelyHood is -86.53572760898568
# iteration is 52
# likelyHood is -85.95991639453001
# iteration is 53
# likelyHood is -85.40672674422653
# iteration is 54
# likelyHood is -84.87488537013583
# iteration is 55
# likelyHood is -84.36321158563479
# iteration is 56
# likelyHood is -83.87060907042331
# iteration is 57
# likelyHood is -83.39605849930761
# iteration is 58
# likelyHood is -82.9386109307728
# iteration is 59
# likelyHood is -82.49738186540877
# iteration is 60
# likelyHood is -82.07154589622156
# iteration is 61
# likelyHood is -81.66033188306581
# iteration is 62
# likelyHood is -81.26301859215904
# iteration is 63
# likelyHood is -80.87893074912797
# iteration is 64
# likelyHood is -80.50743546047134
# iteration is 65
# likelyHood is -80.14793896387081
# iteration is 66
# likelyHood is -79.79988367256982
# iteration is 67
# likelyHood is -79.46274548319221
# iteration is 68
# likelyHood is -79.13603131997068
# iteration is 69
# likelyHood is -78.81927689148407
# iteration is 70
# likelyHood is -78.5120446387323
# iteration is 71
# likelyHood is -78.21392185576046
# iteration is 72
# likelyHood is -77.92451896612205
# iteration is 73
# likelyHood is -77.6434679403084
# iteration is 74
# likelyHood is -77.37042084086914
# iteration is 75
# likelyHood is -77.10504848336079
# iteration is 76
# likelyHood is -76.84703920251044
# iteration is 77
# likelyHood is -76.59609771407823
# iteration is 78
# likelyHood is -76.35194406387367
# iteration is 79
# likelyHood is -76.11431265624645
# iteration is 80
# likelyHood is -75.88295135513529
# iteration is 81
# likelyHood is -75.65762065143748
# iteration is 82
# likelyHood is -75.43809289107334
# iteration is 83
# likelyHood is -75.22415155864967
# iteration is 84
# likelyHood is -75.01559061212032
# iteration is 85
# likelyHood is -74.81221386426488
# iteration is 86
# likelyHood is -74.6138344071957
# iteration is 87
# likelyHood is -74.42027407645269
# iteration is 88
# likelyHood is -74.23136295155189
# iteration is 89
# likelyHood is -74.0469388901366
# iteration is 90
# likelyHood is -73.86684709313262
# iteration is 91
# likelyHood is -73.69093969853158
# iteration is 92
# likelyHood is -73.51907540164045
# iteration is 93
# likelyHood is -73.3511190998099
# iteration is 94
# likelyHood is -73.18694155982801
# iteration is 95
# likelyHood is -73.02641910632188
# iteration is 96
# likelyHood is -72.86943332963428
# ...
# iteration is 37
# likelyHood is -71.06058008177551
# iteration is 38
# likelyHood is -69.76154092854946
# iteration is 39
# likelyHood is -68.50161693772803
# iteration is 40
# likelyHood is -67.27955083252475
# iteration is 41
# likelyHood is -66.09411946720154
# iteration is 42
# likelyHood is -64.94413388935332
# iteration is 43
# likelyHood is -63.828439255827135
# iteration is 44
# likelyHood is -62.745914619362075
# iteration is 45
# likelyHood is -61.6954726028148
# iteration is 46
# likelyHood is -60.676058977155066
# iteration is 47
# likelyHood is -59.686652158408016
# iteration is 48
# likelyHood is -58.726262637502465
# iteration is 49
# likelyHood is -57.79393235565268
# iteration is 50
# likelyHood is -56.888734036532135
# iteration is 51
# likelyHood is -56.009770485147655
# iteration is 52
# likelyHood is -55.15617386203294
# iteration is 53
# likelyHood is -54.32710494018086
# iteration is 54
# likelyHood is -53.521752351036284
# iteration is 55
# likelyHood is -52.73933182488771
# iteration is 56
# likelyHood is -51.97908543012335
# iteration is 57
# likelyHood is -51.24028081505673
# iteration is 58
# likelyHood is -50.52221045536522
# iteration is 59
# likelyHood is -49.8241909096236
# iteration is 60
# likelyHood is -49.14556208493073
# iteration is 61
# likelyHood is -48.485686514226586
# iteration is 62
# likelyHood is -47.84394864655543
# iteration is 63
# likelyHood is -47.21975415125043
# iteration is 64
# likelyHood is -46.61252923678087
# iteration is 65
# likelyHood is -46.02171998481073
# iteration is 66
# likelyHood is -45.44679169986049
# iteration is 67
# likelyHood is -44.8872282748325
# iteration is 68
# likelyHood is -44.34253157255836
# iteration is 69
# likelyHood is -43.812220823436846
# iteration is 70
# likelyHood is -43.29583203916423
# iteration is 71
# likelyHood is -42.79291744249992
# iteration is 72
# likelyHood is -42.303044912964445
# iteration is 73
# likelyHood is -41.82579744832852
# iteration is 74
# likelyHood is -41.36077264172148
# iteration is 75
# likelyHood is -40.90758217416028
# iteration is 76
# likelyHood is -40.46585132228049
# iteration is 77
# likelyHood is -40.035218481031876
# iteration is 78
# likelyHood is -39.61533470108751
# iteration is 79
# likelyHood is -39.205863240702094
# iteration is 80
# likelyHood is -38.806479131745874
# iteration is 81
# likelyHood is -38.416868759630745
# iteration is 82
# likelyHood is -38.03672945683977
# iteration is 83
# likelyHood is -37.66576910976353
# iteration is 84
# likelyHood is -37.30370577854415
# iteration is 85
# likelyHood is -36.95026732962162
# iteration is 86
# likelyHood is -36.605191080677116
# iteration is 87
# likelyHood is -36.268223457663915
# iteration is 88
# likelyHood is -35.939119663616104
# iteration is 89
# likelyHood is -35.617643358925406
# iteration is 90
# likelyHood is -35.303566352776066
# iteration is 91
# likelyHood is -34.99666830542886
# iteration is 92
# likelyHood is -34.69673644104718
# iteration is 93
# likelyHood is -34.4035652707598
# iteration is 94
# likelyHood is -34.116956325658265
# iteration is 95
# likelyHood is -33.83671789942885
# iteration is 96
# likelyHood is -33.56266480032439
# iteration is 97
# likelyHood is -33.29461811218352
# iteration is 98
# likelyHood is -33.0324049642101
# iteration is 99
# likelyHood is -32.7758583092311
# iteration is 100
# likelyHood is -32.52481671015432
# iteration is 101
# likelyHood is -32.27912413435464
# iteration is 102
# likelyHood is -32.03862975572206
# iteration is 103
# likelyHood is -31.803187764110312
# iteration is 104
# likelyHood is -31.572657181931397
# iteration is 105
# likelyHood is -31.346901687647545
# iteration is 106
# likelyHood is -31.125789445916958
# iteration is 107
# likelyHood is -30.909192944158036
# iteration is 108
# likelyHood is -30.696988835301063
# iteration is 109
# likelyHood is -30.489057786504095
# iteration is 110
# likelyHood is -30.285284333615568
# iteration is 111
# likelyHood is -30.08555674117232
# iteration is 112
# likelyHood is -29.889766867728632
# iteration is 113
# likelyHood is -29.697810036317577
# iteration is 114
# likelyHood is -29.509584909852713
# iteration is 115
# likelyHood is -29.32499337128366
# iteration is 116
# likelyHood is -29.14394040832602
# iteration is 117
# likelyHood is -28.96633400259128
# iteration is 118
# likelyHood is -28.79208502294862
# iteration is 119
# likelyHood is -28.621107122956342
# iteration is 120
# likelyHood is -28.453316642206048
# iteration is 121
# likelyHood is -28.288632511428304
# iteration is 122
# likelyHood is -28.126976161214163
# iteration is 123
# likelyHood is -27.968271434211488
# iteration is 124
# likelyHood is -27.812444500661307
# iteration is 125
# likelyHood is -27.65942377714289
# iteration is 126
# likelyHood is -27.50913984840274
# iteration is 127
# likelyHood is -27.36152539214567
# iteration is 128
# likelyHood is -27.216515106672432
# iteration is 129
# likelyHood is -27.074045641251363
# iteration is 130
# likelyHood is -26.93405552911667
# iteration is 131
# likelyHood is -26.79648512298944
# iteration is 132
# likelyHood is -26.661276533022665
# iteration is 133
# likelyHood is -26.528373567073555
# iteration is 134
# likelyHood is -26.397721673212114
# iteration is 135
# likelyHood is -26.269267884377335
# iteration is 136
# likelyHood is -26.142960765096195
# iteration is 137
# likelyHood is -26.018750360184082
# iteration is 138
# likelyHood is -25.89658814534845
# iteration is 139
# likelyHood is -25.776426979620588
# iteration is 140
# likelyHood is -25.65822105954343
# iteration is 141
# likelyHood is -25.541925875046303
# iteration is 142
# likelyHood is -25.427498166940044
# iteration is 143
# likelyHood is -25.314895885968852
# iteration is 144
# likelyHood is -25.20407815335776
# iteration is 145
# likelyHood is -25.095005222796974
# iteration is 146
# likelyHood is -24.987638443806663
# iteration is 147
# likelyHood is -24.881940226428615
# iteration is 148
# likelyHood is -24.777874007192164
# iteration is 149
# likelyHood is -24.67540421630541
# iteration is 150
# likelyHood is -24.574496246023614
# iteration is 151
# likelyHood is -24.47511642014902
# iteration is 152
# likelyHood is -24.377231964618353
# iteration is 153
# likelyHood is -24.280810979135712
# iteration is 154
# likelyHood is -24.18582240981042
# iteration is 155
# likelyHood is -24.092236022761348
# iteration is 156
# likelyHood is -24.00002237865009
# iteration is 157
# likelyHood is -23.90915280810764
# iteration is 158
# likelyHood is -23.819599388020134
# iteration is 159
# likelyHood is -23.73133491864095
# iteration is 160
# likelyHood is -23.644332901497535
# iteration is 161
# likelyHood is -23.55856751806286
# iteration is 162
# likelyHood is -23.474013609162142
# iteration is 163
# likelyHood is -23.390646655087604
# iteration is 164
# likelyHood is -23.30844275639376
# iteration is 165
# likelyHood is -23.22737861534835
# iteration is 166
# likelyHood is -23.14743151801381
# iteration is 167
# likelyHood is -23.068579316935725
# iteration is 168
# likelyHood is -22.990800414415784
# iteration is 169
# likelyHood is -22.914073746347324
# iteration is 170
# likelyHood is -22.838378766592527
# iteration is 171
# likelyHood is -22.763695431881295
# iteration is 172
# likelyHood is -22.690004187212576
# iteration is 173
# likelyHood is -22.617285951739433
# iteration is 174
# likelyHood is -22.545522105120313
# iteration is 175
# likelyHood is -22.474694474319488
# iteration is 176
# likelyHood is -22.404785320839913
# iteration is 177
# likelyHood is -22.335777328373187
# iteration is 178
# likelyHood is -22.267653590851342
# iteration is 179
# likelyHood is -22.20039760088574
# iteration is 180
# likelyHood is -22.13399323857954
# iteration is 181
# likelyHood is -22.068424760699838
# iteration is 182
# likelyHood is -22.003676790196963
# iteration is 183
# likelyHood is -21.93973430605843
# iteration is 184
# likelyHood is -21.876582633485388
# iteration is 185
# likelyHood is -21.8142074343807
# iteration is 186
# likelyHood is -21.752594698136967
# iteration is 187
# likelyHood is -21.691730732714415
# iteration is 188
# likelyHood is -21.631602155998262
# iteration is 189
# likelyHood is -21.572195887425792
# iteration is 190
# likelyHood is -21.51349913987375
# iteration is 191
# likelyHood is -21.455499411797007
# iteration is 192
# likelyHood is -21.39818447960978
# iteration is 193
# likelyHood is -21.34154239030105
# iteration is 194
# likelyHood is -21.285561454275957
# iteration is 195
# likelyHood is -21.230230238415828
# iteration is 196
# likelyHood is -21.175537559348783
# iteration is 197
# likelyHood is -21.121472476924215
# iteration is 198
# likelyHood is -21.06802428788403
# iteration is 199
# likelyHood is -21.015182519723993
# iteration is 200
# likelyHood is -20.96293692473874
# iteration is 201
# likelyHood is -20.91127747424444
# iteration is 202
# likelyHood is -20.860194352972798
# iteration is 203
# likelyHood is -20.809677953631244
# iteration is 204
# likelyHood is -20.759718871623164
# iteration is 205
# likelyHood is -20.710307899923325
# iteration is 206
# likelyHood is -20.66143602410307
# iteration is 207
# likelyHood is -20.613094417500644
# iteration is 208
# likelyHood is -20.56527443653147
# iteration is 209
# likelyHood is -20.517967616134325
# iteration is 210
# likelyHood is -20.471165665348465
# iteration is 211
# likelyHood is -20.42486046301782
# iteration is 212
# likelyHood is -20.37904405361802
# iteration is 213
# likelyHood is -20.333708643202232
# iteration is 214
# likelyHood is -20.28884659546203
# iteration is 215
# likelyHood is -20.244450427899693
# iteration is 216
# likelyHood is -20.200512808108233
# iteration is 217
# likelyHood is -20.15702655015587
# iteration is 218
# likelyHood is -20.113984611071537
# iteration is 219
# likelyHood is -20.07138008742821
# iteration is 220
# likelyHood is -20.029206212021133
# iteration is 221
# likelyHood is -19.987456350637764
# iteration is 222
# likelyHood is -19.946123998916782
# iteration is 223
# likelyHood is -19.905202779293102
# iteration is 224
# likelyHood is -19.86468643802664
# iteration is 225
# likelyHood is -19.82456884231168
# iteration is 226
# likelyHood is -19.78484397746497
# iteration is 227
# likelyHood is -19.74550594418962
# iteration is 228
# likelyHood is -19.70654895591284
# iteration is 229
# likelyHood is -19.667967336194987
# iteration is 230
# likelyHood is -19.629755516207897
# iteration is 231
# likelyHood is -19.591908032280564
# iteration is 232
# likelyHood is -19.554419523509637
# iteration is 233
# likelyHood is -19.517284729433406
# iteration is 234
# likelyHood is -19.48049848776691
# iteration is 235
# likelyHood is -19.44405573219646
# iteration is 236
# likelyHood is -19.407951490232012
# iteration is 237
# likelyHood is -19.372180881115323
# iteration is 238
# likelyHood is -19.336739113782606
# iteration is 239
# likelyHood is -19.301621484879654
# iteration is 240
# likelyHood is -19.266823376828427
# iteration is 241
# likelyHood is -19.232340255943065
# iteration is 242
# likelyHood is -19.198167670594163
# iteration is 243
# likelyHood is -19.164301249420024
# iteration is 244
# likelyHood is -19.13073669958317
# iteration is 245
# likelyHood is -19.097469805070997
# iteration is 246
# likelyHood is -19.064496425039565
# iteration is 247
# likelyHood is -19.031812492198707
# iteration is 248
# likelyHood is -18.999414011237747
# iteration is 249
# likelyHood is -18.96729705729056
# iteration is 250
# likelyHood is -18.935457774438717
# iteration is 251
# likelyHood is -18.9038923742518
# iteration is 252
# likelyHood is -18.872597134363716
# iteration is 253
# likelyHood is -18.84156839708416
# iteration is 254
# likelyHood is -18.81080256804397
# iteration is 255
# likelyHood is -18.780296114873785
# iteration is 256
# likelyHood is -18.750045565914785
# iteration is 257
# likelyHood is -18.720047508960672
# iteration is 258
# likelyHood is -18.6902985900302
# iteration is 259
# likelyHood is -18.660795512169276
# iteration is 260
# likelyHood is -18.631535034281793
# iteration is 261
# likelyHood is -18.602513969988397
# iteration is 262
# likelyHood is -18.573729186512683
# iteration is 263
# likelyHood is -18.545177603593718
# iteration is 264
# likelyHood is -18.51685619242426
# iteration is 265
# likelyHood is -18.48876197461434
# iteration is 266
# likelyHood is -18.4608920211789
# iteration is 267
# likelyHood is -18.433243451549462
# iteration is 268
# likelyHood is -18.40581343260872
# iteration is 269
# likelyHood is -18.378599177747613
# iteration is 270
# likelyHood is -18.351597945944565
# iteration is 271
# likelyHood is -18.324807040865583
# iteration is 272
# likelyHood is -18.298223809985554
# iteration is 273
# likelyHood is -18.27184564372945
# iteration is 274
# likelyHood is -18.245669974633408
# iteration is 275
# likelyHood is -18.219694276524752
# iteration is 276
# likelyHood is -18.193916063720856
# iteration is 277
# likelyHood is -18.168332890246127
# iteration is 278
# likelyHood is -18.14294234906672
# iteration is 279
# likelyHood is -18.117742071342402
# iteration is 280
# likelyHood is -18.092729725695335
# iteration is 281
# likelyHood is -18.06790301749521
# iteration is 282
# likelyHood is -18.04325968816022
# iteration is 283
# likelyHood is -18.018797514473754
# iteration is 284
# likelyHood is -17.994514307916184
# iteration is 285
# likelyHood is -17.970407914011304
# iteration is 286
# likelyHood is -17.94647621168732
# iteration is 287
# likelyHood is -17.92271711265184
# iteration is 288
# likelyHood is -17.89912856078044
# iteration is 289
# likelyHood is -17.875708531518704
# iteration is 290
# likelyHood is -17.852455031297225
# iteration is 291
# likelyHood is -17.829366096959234
# iteration is 292
# likelyHood is -17.80643979520061
# iteration is 293
# likelyHood is -17.783674222022146
# iteration is 294
# likelyHood is -17.76106750219319
# iteration is 295
# likelyHood is -17.738617788727186
# iteration is 296
# likelyHood is -17.716323262368082
# iteration is 297
# likelyHood is -17.694182131087906
# iteration is 298
# likelyHood is -17.672192629594814
# iteration is 299
# likelyHood is -17.650353018851582
# iteration is 300
# likelyHood is -17.628661585604426
# iteration is 301
# likelyHood is -17.60711664192136
# iteration is 302
# likelyHood is -17.585716524740636
# iteration is 303
# likelyHood is -17.56445959542824
# iteration is 304
# likelyHood is -17.543344239344897
# iteration is 305
# likelyHood is -17.52236886542184
# iteration is 306
# likelyHood is -17.501531905745516
# iteration is 307
# likelyHood is -17.480831815150776
# iteration is 308
# likelyHood is -17.460267070822397
# iteration is 309
# likelyHood is -17.439836171904872
# iteration is 310
# likelyHood is -17.419537639120072
# iteration is 311
# likelyHood is -17.3993700143929
# iteration is 312
# likelyHood is -17.379331860484147
# iteration is 313
# likelyHood is -17.35942176063127
# iteration is 314
# likelyHood is -17.339638318196045
# iteration is 315
# likelyHood is -17.31998015631953
# iteration is 316
# likelyHood is -17.30044591758387
# iteration is 317
# likelyHood is -17.281034263680898
# iteration is 318
# likelyHood is -17.261743875087266
# iteration is 319
# likelyHood is -17.24257345074621
# iteration is 320
# likelyHood is -17.223521707755474
# iteration is 321
# likelyHood is -17.204587381061444
# iteration is 322
# likelyHood is -17.185769223159355
# iteration is 323
# likelyHood is -17.16706600379935
# iteration is 324
# likelyHood is -17.148476509698355
# iteration is 325
# likelyHood is -17.129999544257494
# iteration is 326
# likelyHood is -17.111633927285116
# iteration is 327
# likelyHood is -17.093378494725126
# iteration is 328
# likelyHood is -17.075232098390615
# iteration is 329
# likelyHood is -17.057193605702665
# iteration is 330
# likelyHood is -17.0392618994341
# iteration is 331
# likelyHood is -17.02143587745828
# iteration is 332
# likelyHood is -17.00371445250258
# iteration is 333
# likelyHood is -16.9860965519067
# iteration is 334
# likelyHood is -16.96858111738546
# iteration is 335
# likelyHood is -16.95116710479625
# iteration is 336
# likelyHood is -16.93385348391067
# iteration is 337
# likelyHood is -16.916639238190736
# iteration is 338
# likelyHood is -16.89952336456908
# iteration is 339
# likelyHood is -16.88250487323347
# iteration is 340
# likelyHood is -16.86558278741515
# iteration is 341
# likelyHood is -16.848756143181348
# col_0  0.0  1.0
# row_0
# 0       29    1
# value is 3
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 0        0    2
# 1        1    2
# value is 4
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1   30
# value is 5
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1  258
# value is 6
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1  413
# value is 7
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1  147
# value is 8
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1   29
# value is 9
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 0       29    1

# %%
for i in conMatrix:
    print("value is "+str(i))
    print("its confusion matrix is")
    print(conMatrix[i])
# Out:
# value is 3
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 0        0    2
# 1        1    2
# value is 4
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1   30
# value is 5
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1  258
# value is 6
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1  413
# value is 7
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1  147
# value is 8
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 1        1   29
# value is 9
# its confusion matrix is
# col_0  0.0  1.0
# row_0
# 0       29    1

# %% [markdown]
# import itertools
# list(itertools.combinations(np.unique(train['quality"""']), 2))
# for eachvalue in list(itertools.combinations(np.unique(train['quality"""']), 2)):
#     print(eachvalue[1])
# for x in train['quality"""']:
#     trainYvector = []
#     temp1 = 999
#     if x == eachvalue[0]:
#         temp1 = 1.0
#     elif x == eachvalue[1]:
#         temp1 = 0.0
#     if(temp1!=999):
#         trainYvector.append(temp1)
#     trainYvector = np.array(trainYvector)
#
# for x in val['quality"""']:
#     valYvector = []
#     temp1 = 999
#     if x == eachvalue[0]:
#         temp1 = 1.0
#     elif x == eachvalue[1]:
#         temp1 = 0.0
#     if(temp1!=999):
#         valYvector.append(temp1)
#     valYvector = np.array(valYvector)
#
#
# trainYvector = np.array([1.0 if x == eachvalue[0] elif x == eachvalue[1] 0.0 for x in train['quality"""']])
# valYvector = np.array([1.0 if x == eachvalue[0] elif x == eachvalue[1] 0.0 for x in val['quality"""']])
