# %%
import pandas as pd 
import numpy as np
import copy

#data = pd.read_csv("train.csv") 
#ran = np.random.rand(len(data)) < 0.8
#train = data[ran]
#val = data[~ran]
#train.to_csv('UsedTrainingData.csv')
#val.to_csv('UsedValidationData.csv')

train =  pd.read_csv('UsedTrainingData.csv')
val = pd.read_csv('UsedValidationData.csv')

targetAttribute = 'left'
Attributes = list(train.columns)
Attributes.remove(targetAttribute)
examples = list(train.index.values) 

NumericalAttributes = ['satisfaction_level', 'last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company']
CategoricalAttributes = ['Work_accident', 'promotion_last_5years', 'sales', 'salary']

def getImpurityOfExamples(examplesForCurNode,method):
    NumberOfPosEx = 0
    NumberOfNegEx = 0
    for j in examplesForCurNode:
        if  str(train.at[int(j),targetAttribute]) == str(1):
            NumberOfPosEx = NumberOfPosEx+1
        elif str(train.at[int(j),targetAttribute]) == str(0):
             NumberOfNegEx = NumberOfNegEx+1
    PropOfPos =  NumberOfPosEx/len(examplesForCurNode)
    PropOfNeg = NumberOfNegEx/len(examplesForCurNode)
    if method == 'Gini':
        return (2*PropOfPos*PropOfNeg)
    elif method == 'misClasifi':
        return min(PropOfPos,PropOfNeg)
    elif method == 'Entropy':
        if PropOfPos == 0:
            return (-1*PropOfNeg*(np.log(PropOfNeg)/np.log(2)))
        elif PropOfNeg == 0:
            return (-1*PropOfPos*(np.log(PropOfPos)/np.log(2)))
        else:
            return ((-1*PropOfPos*(np.log(PropOfPos)/np.log(2))) + (-1*PropOfNeg*(np.log(PropOfNeg)/np.log(2))))

def getMethodImpurity(Attribute,value,examplesForCurAttr,method): 
    fra1 = train.loc[examplesForCurAttr,:]
    LessThanExamples = []
    MoreThanExamples = []
    if Attribute in NumericalAttributes: 
        for j in examplesForCurAttr:
            if  float(str(fra1.at[int(j),Attribute])) <= float(str(value)):
                LessThanExamples.append(int(j))
            else:
                MoreThanExamples.append(int(j))
    else:
        for j in examplesForCurAttr:
            if  str(fra1.at[int(j),Attribute]) == str(value):
                LessThanExamples.append(int(j))
            else:
                MoreThanExamples.append(int(j))
        
    if len(LessThanExamples) <=0 or len(MoreThanExamples) <= 0:    
        return 999
    else:  
        return ((len(LessThanExamples)*getImpurityOfExamples(LessThanExamples,method))+(len(MoreThanExamples)*getImpurityOfExamples(MoreThanExamples,method)))/len(examplesForCurAttr)
    
class Node(object):
    def __init__(self,examples,decisionAttributeType,decisionAttribute,decisionAttributeValue,level):
        self.examples = examples
        self.decisionAttributeType = decisionAttributeType
        self.decisionAttribute = decisionAttribute        
        self.decisionAttributeValue = decisionAttributeValue
        self.level = level
        self.leftChild = None
        self.rightChild = None
        
    def __str__(self): 
        return "Decision attribute type is "+self.decisionAttributeType+"decisionAttribute is "+ self.decisionAttribute+" decisionAttributeValue is "+ str(self.decisionAttributeValue)+" of level "+str(self.level)+" number of examples of this node "+str(len(self.examples))
    
def BestOfAttributes(examplesForCurAttr,targetAttribute,method):
    fra1 = train.loc[examplesForCurAttr,CategoricalAttributes]
    dictForCategAttrUniqueValues = {}
    for i in CategoricalAttributes:
        dictForCategAttrUniqueValues[i] = list(fra1[i].sort_values().unique())
    dictForEntropyUniqueValueCateg = copy.deepcopy(dictForCategAttrUniqueValues)
    print("calculating Impurities please wait")
    for i in CategoricalAttributes:
        for j,val in enumerate(dictForCategAttrUniqueValues[i]):
            dictForEntropyUniqueValueCateg[i][j] = getMethodImpurity(i,dictForCategAttrUniqueValues[i][j],examplesForCurAttr,method)          
    EntropyValuesForCategoricalAttributes = {}
    for i in CategoricalAttributes:
        EntropyValuesForCategoricalAttributes[i]=min(dictForEntropyUniqueValueCateg[i])
    BestOfCategoricalAttributes = min(EntropyValuesForCategoricalAttributes, key=EntropyValuesForCategoricalAttributes.get)
    BestOfCategoricalAttributesValue = min(EntropyValuesForCategoricalAttributes.values())   
    
    fra1 = train.loc[examplesForCurAttr,NumericalAttributes]
    dictForNumAttrUniqueValues = {}
    for i in NumericalAttributes:
        dictForNumAttrUniqueValues[i] = list(fra1[i].sort_values().unique())
    dictForEntropyUniqueValueNum = copy.deepcopy(dictForNumAttrUniqueValues)
    
    print("calculating Impurities please wait")
    for i in NumericalAttributes:
        for j,val in enumerate(dictForNumAttrUniqueValues[i]):
            dictForEntropyUniqueValueNum[i][j] = getMethodImpurity(i,dictForNumAttrUniqueValues[i][j],examplesForCurAttr,method)          
    EntropyValuesForNumericalAttributes = {}
    for i in NumericalAttributes:
        EntropyValuesForNumericalAttributes[i]=min(dictForEntropyUniqueValueNum[i])
    BestOfNumericalAttributes = min(EntropyValuesForNumericalAttributes, key=EntropyValuesForNumericalAttributes.get)
    BestOfNumericalAttributesValue = min(EntropyValuesForNumericalAttributes.values())
    
    for index, item in enumerate(dictForEntropyUniqueValueNum[BestOfNumericalAttributes]):
        if item == BestOfNumericalAttributesValue:
            BestSplitValueNumerical = dictForNumAttrUniqueValues[BestOfNumericalAttributes][index]
            break
            
    for index, item in enumerate(dictForEntropyUniqueValueCateg[BestOfCategoricalAttributes]):
        if item == BestOfCategoricalAttributesValue:
            BestSplitValueCategorical = dictForCategAttrUniqueValues[BestOfCategoricalAttributes][index]
            break

    if BestOfNumericalAttributesValue < BestOfCategoricalAttributesValue:
        return BestOfNumericalAttributes,BestSplitValueNumerical
    else: 
        return BestOfCategoricalAttributes,BestSplitValueCategorical
    
def DecisionTreeBuilder(examplesForCurNode,targetAttribute,level,method):
    allExPos = True
    for i in examplesForCurNode:
        if str(train.at[int(i),targetAttribute]) == str(1):
            pass
        else:
            allExPos = False
            break
    if allExPos:        
        r = Node(examplesForCurNode,'leafNode','leafNode','Positive',level)
        print(r)
        print("Type1")
        return r
    allExNeg = True
    for j in examplesForCurNode:
        if str(train.at[j,targetAttribute]) == str(0):
            pass
        else:
            allExNeg = False
            break
    if allExNeg:
        r = Node(examplesForCurNode,'leafNode','leafNode','Negative',level)
        print(r)
        print("Type2")
        return r
    if getImpurityOfExamples(examplesForCurNode,method) < 0.001 or len(examplesForCurNode)<10:
        fra1 = train.loc[examplesForCurNode,[targetAttribute] ]
        targetAttributesList = fra1[targetAttribute].values
        unique1, counts1 = np.unique(targetAttributesList, return_counts=True)
        dictOfTaAttr = dict(zip(unique1, counts1))
        posCount = dictOfTaAttr[1]
        negCount = dictOfTaAttr[0]
        if (posCount/(posCount+negCount))>0.5:
            r = Node(examplesForCurNode,'leafNode','leafNode','Positive',level)
            #numberOfNodes  = numberOfNodes + 1
        else:
            r = Node(examplesForCurNode,'leafNode','leafNode','Negative',level)
            #numberOfNodes  = numberOfNodes + 1
        print(r)
        print("Type3")
        return r
    
    BestAttribute,BestAttributeValue = BestOfAttributes(examplesForCurNode,targetAttribute,method)
    
    if BestAttribute in NumericalAttributes:
        BestAttributeType = 'numerical'
    else:
        BestAttributeType = 'categorical'
    r = Node(examplesForCurNode,BestAttributeType,BestAttribute,BestAttributeValue,level)
    print(r)
    print("Type4")
    #numberOfNodes  = numberOfNodes + 1
    examplesForLeftChildOfCurrentNode = []
    examplesForRightChildOfCurrentNode = []        
    if BestAttributeType == 'categorical':        
        for iter1 in examplesForCurNode:
            if  str(train.at[int(iter1),str(BestAttribute)]) == str(BestAttributeValue):
                examplesForLeftChildOfCurrentNode.append(int(iter1))
            else:
                examplesForRightChildOfCurrentNode.append(int(iter1))
    else:
        for iter1 in examplesForCurNode:
            if  float(str(train.at[int(iter1),str(BestAttribute)])) <= float(str(BestAttributeValue)):
                examplesForLeftChildOfCurrentNode.append(int(iter1))
            else:
                examplesForRightChildOfCurrentNode.append(int(iter1))
    r.leftChild = DecisionTreeBuilder(examplesForLeftChildOfCurrentNode,targetAttribute,level+1,method)
    r.rightChild = DecisionTreeBuilder(examplesForRightChildOfCurrentNode,targetAttribute,level+1,method)
    
    return r

# %%
examplesForRootNode = examples[:]
method = 'misClasifi'
RootNode = DecisionTreeBuilder(examplesForRootNode,targetAttribute,0,method)
# Out:
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.46 of level 0 number of examples of this node 8989
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is time_spend_company decisionAttributeValue is 4 of level 1 number of examples of this node 2501
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is time_spend_company decisionAttributeValue is 2 of level 2 number of examples of this node 2060
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.13 of level 3 number of examples of this node 169
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 4 number of examples of this node 8
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.38 of level 4 number of examples of this node 161
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 5 number of examples of this node 7
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is Work_accident decisionAttributeValue is 0 of level 5 number of examples of this node 154
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is promotion_last_5years decisionAttributeValue is 0 of level 6 number of examples of this node 131
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is IT of level 7 number of examples of this node 130
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 8 number of examples of this node 9
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is RandD of level 8 number of examples of this node 121
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 9 number of examples of this node 9
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is accounting of level 9 number of examples of this node 112
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 10 number of examples of this node 8
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is management of level 10 number of examples of this node 104
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 11 number of examples of this node 5
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is hr of level 11 number of examples of this node 99
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 12 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.14 of level 12 number of examples of this node 96
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 13 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is marketing of level 13 number of examples of this node 95
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 14 number of examples of this node 4
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.19 of level 14 number of examples of this node 91
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 15 number of examples of this node 8
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is product_mng of level 15 number of examples of this node 83
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 16 number of examples of this node 10
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is sales of level 16 number of examples of this node 73
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is average_montly_hours decisionAttributeValue is 272 of level 17 number of examples of this node 38
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is high of level 18 number of examples of this node 37
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 19 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is low of level 19 number of examples of this node 35
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.23 of level 20 number of examples of this node 27
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 21 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.26 of level 21 number of examples of this node 25
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 22 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.32 of level 22 number of examples of this node 24
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 23 number of examples of this node 5
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.34 of level 23 number of examples of this node 19
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 24 number of examples of this node 2
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 24 number of examples of this node 17
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 20 number of examples of this node 8
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 18 number of examples of this node 1
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is support of level 17 number of examples of this node 35
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 18 number of examples of this node 16
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is high of level 18 number of examples of this node 19
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 19 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is low of level 19 number of examples of this node 18
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 20 number of examples of this node 13
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 20 number of examples of this node 5
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 7 number of examples of this node 1
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 6 number of examples of this node 23
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is average_montly_hours decisionAttributeValue is 125 of level 3 number of examples of this node 1891
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 4 number of examples of this node 65
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.44 of level 4 number of examples of this node 1826
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 5 number of examples of this node 44
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is high of level 5 number of examples of this node 1782
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is number_project decisionAttributeValue is 2 of level 6 number of examples of this node 89
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.57 of level 7 number of examples of this node 34
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is IT of level 8 number of examples of this node 31
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 9 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is Work_accident decisionAttributeValue is 0 of level 9 number of examples of this node 29
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 10 number of examples of this node 28
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 10 number of examples of this node 1
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 8 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.1 of level 7 number of examples of this node 55
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 8 number of examples of this node 9
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is Work_accident decisionAttributeValue is 0 of level 8 number of examples of this node 46
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is promotion_last_5years decisionAttributeValue is 0 of level 9 number of examples of this node 40
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is IT of level 10 number of examples of this node 37
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 11 number of examples of this node 4
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is RandD of level 11 number of examples of this node 33
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 12 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is accounting of level 12 number of examples of this node 32
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 13 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is hr of level 13 number of examples of this node 30
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 14 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is management of level 14 number of examples of this node 29
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 15 number of examples of this node 4
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is marketing of level 15 number of examples of this node 25
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 16 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is product_mng of level 16 number of examples of this node 22
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 17 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is sales of level 17 number of examples of this node 19
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 18 number of examples of this node 9
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.15 of level 18 number of examples of this node 10
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 19 number of examples of this node 1
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 19 number of examples of this node 9
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 10 number of examples of this node 3
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 9 number of examples of this node 6
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is average_montly_hours decisionAttributeValue is 155 of level 6 number of examples of this node 1693
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is number_project decisionAttributeValue is 2 of level 7 number of examples of this node 805
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.57 of level 8 number of examples of this node 752
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.31 of level 9 number of examples of this node 742
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 10 number of examples of this node 3
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is promotion_last_5years decisionAttributeValue is 0 of level 10 number of examples of this node 739
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is Work_accident decisionAttributeValue is 0 of level 11 number of examples of this node 735
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is IT of level 12 number of examples of this node 692
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 13 number of examples of this node 48
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is RandD of level 13 number of examples of this node 644
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 14 number of examples of this node 18
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.52 of level 14 number of examples of this node 626
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is accounting of level 15 number of examples of this node 412
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 16 number of examples of this node 34
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is hr of level 16 number of examples of this node 378
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 17 number of examples of this node 38
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.38 of level 17 number of examples of this node 340
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 18 number of examples of this node 103
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is management of level 18 number of examples of this node 237
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 19 number of examples of this node 8
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is marketing of level 19 number of examples of this node 229
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 20 number of examples of this node 25
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is support of level 20 number of examples of this node 204
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 21 number of examples of this node 43
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is product_mng of level 21 number of examples of this node 161
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 22 number of examples of this node 16
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.43 of level 22 number of examples of this node 145
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is sales of level 23 number of examples of this node 98
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.42 of level 24 number of examples of this node 61
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is low of level 25 number of examples of this node 49
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.39 of level 26 number of examples of this node 35
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 27 number of examples of this node 5
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.4 of level 27 number of examples of this node 30
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 28 number of examples of this node 11
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.41 of level 28 number of examples of this node 19
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 29 number of examples of this node 9
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is average_montly_hours decisionAttributeValue is 147 of level 29 number of examples of this node 10
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 30 number of examples of this node 9
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 30 number of examples of this node 1
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 26 number of examples of this node 14
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 25 number of examples of this node 12
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 24 number of examples of this node 37
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 23 number of examples of this node 47
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is accounting of level 15 number of examples of this node 214
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 16 number of examples of this node 12
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is product_mng of level 16 number of examples of this node 202
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 17 number of examples of this node 15
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is hr of level 17 number of examples of this node 187
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 18 number of examples of this node 18
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is sales of level 18 number of examples of this node 169
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 19 number of examples of this node 71
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is management of level 19 number of examples of this node 98
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 20 number of examples of this node 4
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.54 of level 20 number of examples of this node 94
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 21 number of examples of this node 45
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is marketing of level 21 number of examples of this node 49
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 22 number of examples of this node 3
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is support of level 22 number of examples of this node 46
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is low of level 23 number of examples of this node 27
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is average_montly_hours decisionAttributeValue is 132 of level 24 number of examples of this node 18
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 25 number of examples of this node 1
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 25 number of examples of this node 17
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 24 number of examples of this node 9
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 23 number of examples of this node 19
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 12 number of examples of this node 43
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 11 number of examples of this node 4
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is Work_accident decisionAttributeValue is 0 of level 9 number of examples of this node 10
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 10 number of examples of this node 7
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 10 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.94 of level 8 number of examples of this node 53
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is support of level 9 number of examples of this node 52
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 10 number of examples of this node 5
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is Work_accident decisionAttributeValue is 0 of level 10 number of examples of this node 47
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is promotion_last_5years decisionAttributeValue is 0 of level 11 number of examples of this node 35
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is IT of level 12 number of examples of this node 33
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 13 number of examples of this node 4
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is RandD of level 13 number of examples of this node 29
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 14 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is accounting of level 14 number of examples of this node 27
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 15 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is hr of level 15 number of examples of this node 24
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 16 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is management of level 16 number of examples of this node 22
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 17 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is marketing of level 17 number of examples of this node 21
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 18 number of examples of this node 4
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is product_mng of level 18 number of examples of this node 17
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 19 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is number_project decisionAttributeValue is 5 of level 19 number of examples of this node 14
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is sales of level 20 number of examples of this node 13
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is low of level 21 number of examples of this node 11
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 22 number of examples of this node 5
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 22 number of examples of this node 6
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 21 number of examples of this node 2
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 20 number of examples of this node 1
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 12 number of examples of this node 2
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 11 number of examples of this node 12
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 9 number of examples of this node 1
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.11 of level 7 number of examples of this node 888
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 8 number of examples of this node 482
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is average_montly_hours decisionAttributeValue is 161 of level 8 number of examples of this node 406
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.62 of level 9 number of examples of this node 153
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.53 of level 10 number of examples of this node 147
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.3 of level 11 number of examples of this node 98
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 12 number of examples of this node 2
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 12 number of examples of this node 96
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 11 number of examples of this node 49
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 10 number of examples of this node 6
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is number_project decisionAttributeValue is 6 of level 9 number of examples of this node 253
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is average_montly_hours decisionAttributeValue is 287 of level 10 number of examples of this node 249
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is average_montly_hours decisionAttributeValue is 205 of level 11 number of examples of this node 245
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.99 of level 12 number of examples of this node 107
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is Work_accident decisionAttributeValue is 0 of level 13 number of examples of this node 104
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.42 of level 14 number of examples of this node 83
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is IT of level 15 number of examples of this node 77
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 16 number of examples of this node 8
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is RandD of level 16 number of examples of this node 69
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 17 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is accounting of level 17 number of examples of this node 67
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 18 number of examples of this node 4
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is hr of level 18 number of examples of this node 63
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 19 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is management of level 19 number of examples of this node 60
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 20 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is marketing of level 20 number of examples of this node 57
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 21 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is product_mng of level 21 number of examples of this node 55
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 22 number of examples of this node 4
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is sales of level 22 number of examples of this node 51
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 23 number of examples of this node 20
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.41 of level 23 number of examples of this node 31
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is support of level 24 number of examples of this node 27
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 25 number of examples of this node 10
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.73 of level 25 number of examples of this node 17
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 26 number of examples of this node 14
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 26 number of examples of this node 3
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 24 number of examples of this node 4
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 15 number of examples of this node 6
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is promotion_last_5years decisionAttributeValue is 0 of level 14 number of examples of this node 21
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is IT of level 15 number of examples of this node 19
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 16 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is RandD of level 16 number of examples of this node 18
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 17 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is accounting of level 17 number of examples of this node 17
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 18 number of examples of this node 4
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 18 number of examples of this node 13
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 15 number of examples of this node 2
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 13 number of examples of this node 3
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is management of level 12 number of examples of this node 138
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 13 number of examples of this node 2
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is Work_accident decisionAttributeValue is 0 of level 13 number of examples of this node 136
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is IT of level 14 number of examples of this node 112
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 15 number of examples of this node 5
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is last_evaluation decisionAttributeValue is 0.98 of level 15 number of examples of this node 107
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is RandD of level 16 number of examples of this node 102
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 17 number of examples of this node 9
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is accounting of level 17 number of examples of this node 93
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 18 number of examples of this node 5
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.19 of level 18 number of examples of this node 88
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is marketing of level 19 number of examples of this node 41
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 20 number of examples of this node 4
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is product_mng of level 20 number of examples of this node 37
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 21 number of examples of this node 5
# Type2
# calculating Impurities please wait
# ...
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is management of level 21 number of examples of this node 229
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 22 number of examples of this node 4
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.73 of level 22 number of examples of this node 225
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 23 number of examples of this node 19
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is product_mng of level 23 number of examples of this node 206
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 24 number of examples of this node 20
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is sales of level 24 number of examples of this node 186
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 25 number of examples of this node 96
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is support of level 25 number of examples of this node 90
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is high of level 26 number of examples of this node 52
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 27 number of examples of this node 3
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is low of level 27 number of examples of this node 49
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 28 number of examples of this node 28
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.74 of level 28 number of examples of this node 21
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 29 number of examples of this node 1
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.75 of level 29 number of examples of this node 20
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 30 number of examples of this node 1
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.78 of level 30 number of examples of this node 19
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 31 number of examples of this node 2
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is time_spend_company decisionAttributeValue is 5 of level 31 number of examples of this node 17
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 32 number of examples of this node 16
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 32 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is high of level 26 number of examples of this node 38
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 27 number of examples of this node 1
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is low of level 27 number of examples of this node 37
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.74 of level 28 number of examples of this node 20
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 29 number of examples of this node 1
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.77 of level 29 number of examples of this node 19
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 30 number of examples of this node 1
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.8 of level 30 number of examples of this node 18
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 31 number of examples of this node 1
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.81 of level 31 number of examples of this node 17
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 32 number of examples of this node 4
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.83 of level 32 number of examples of this node 13
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 33 number of examples of this node 1
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.84 of level 33 number of examples of this node 12
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 34 number of examples of this node 2
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.85 of level 34 number of examples of this node 10
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 35 number of examples of this node 2
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 35 number of examples of this node 8
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 28 number of examples of this node 17
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is technical of level 16 number of examples of this node 14
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 17 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.88 of level 17 number of examples of this node 13
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 18 number of examples of this node 12
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 18 number of examples of this node 1
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 14 number of examples of this node 1
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 12 number of examples of this node 3
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 11 number of examples of this node 5
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 8 number of examples of this node 45
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 4 number of examples of this node 4
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 3 number of examples of this node 10
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is time_spend_company decisionAttributeValue is 4 of level 2 number of examples of this node 150
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is number_project decisionAttributeValue is 5 of level 3 number of examples of this node 60
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.89 of level 4 number of examples of this node 58
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is Work_accident decisionAttributeValue is 0 of level 5 number of examples of this node 47
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is IT of level 6 number of examples of this node 41
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 7 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is RandD of level 7 number of examples of this node 39
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 8 number of examples of this node 4
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is accounting of level 8 number of examples of this node 35
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 9 number of examples of this node 5
# Type3
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is hr of level 9 number of examples of this node 30
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 10 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is management of level 10 number of examples of this node 28
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 11 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is marketing of level 11 number of examples of this node 26
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 12 number of examples of this node 2
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is product_mng of level 12 number of examples of this node 24
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 13 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is sales decisionAttributeValue is sales of level 13 number of examples of this node 23
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is low of level 14 number of examples of this node 11
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 15 number of examples of this node 5
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 15 number of examples of this node 6
# Type3
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 14 number of examples of this node 12
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 6 number of examples of this node 6
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 5 number of examples of this node 11
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 4 number of examples of this node 2
# Type1
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.58 of level 3 number of examples of this node 90
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 4 number of examples of this node 3
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is categoricaldecisionAttribute is salary decisionAttributeValue is high of level 4 number of examples of this node 87
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 5 number of examples of this node 1
# Type2
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is satisfaction_level decisionAttributeValue is 0.91 of level 5 number of examples of this node 86
# Type4
# calculating Impurities please wait
# calculating Impurities please wait
# Decision attribute type is numericaldecisionAttribute is number_project decisionAttributeValue is 5 of level 6 number of examples of this node 85
# Type4
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Positive of level 7 number of examples of this node 84
# Type1
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 7 number of examples of this node 1
# Type2
# Decision attribute type is leafNodedecisionAttribute is leafNode decisionAttributeValue is Negative of level 6 number of examples of this node 1
# Type2

# %%
def RecursiveFunctionToPredict(i,r,TestSet):
    if r.decisionAttribute == 'leafNode':
        if r.decisionAttributeValue == 'Positive':
            return '1'
        else:
            return '0'
    else:
        if r.decisionAttributeType == 'categorical':            
            AttrValue = str(TestSet.at[int(i),str(r.decisionAttribute)])            
            if AttrValue == str(r.decisionAttributeValue):
                return RecursiveFunctionToPredict(i,r.leftChild,TestSet)
            else:
                return RecursiveFunctionToPredict(i,r.rightChild,TestSet)            
        elif r.decisionAttributeType == 'numerical':            
            AttrValue = float(str(TestSet.at[int(i),str(r.decisionAttribute)]))            
            if AttrValue <= float(str(r.decisionAttributeValue)):
                return RecursiveFunctionToPredict(i,r.leftChild,TestSet)
            else:
                return RecursiveFunctionToPredict(i,r.rightChild,TestSet)
def predict(RootNode,NameOfTestFile):
    GivenTestData = pd.read_csv(str(NameOfTestFile))
    GivenTestData['predict']= [0]*len(GivenTestData)
    for i in list(GivenTestData.index.values):        
        GivenTestData.at[i,'predict'] = RecursiveFunctionToPredict(i,RootNode,GivenTestData)
    return GivenTestData

# %%
    GivenTestData =  train.copy()
    GivenTestData['predict']= [0]*len(GivenTestData)
    for i in list(GivenTestData.index.values):        
        GivenTestData.at[i,'predict'] = RecursiveFunctionToPredict(i,RootNode,GivenTestData)
    
    TN = 0
    FP = 0
    FN = 0
    TP = 0
    for i in list(GivenTestData.index.values):
        if str(GivenTestData.at[i,'left']) == str(1) and str(GivenTestData.at[i,'predict']) == str(1):
            TP = TP + 1
        elif str(GivenTestData.at[i,'left']) == str(1) and str(GivenTestData.at[i,'predict']) == str(0):
            FN = FN + 1
        elif str(GivenTestData.at[i,'left']) == str(0) and str(GivenTestData.at[i,'predict']) == str(1):
            FP = FP + 1
        elif str(GivenTestData.at[i,'left']) == str(0) and str(GivenTestData.at[i,'predict']) == str(0):
            TN = TN + 1
    print("Results On Training Data")
    print("Using MissClassification Rate as impurity measure")
    print("-------------------------------------------------")
    print("True Positive are    "+ str(TP))
    print("True Negatives are   "+ str(TN))
    print("False Positive are   "+ str(FP))
    print("False Negatives are  "+str(FN))
    
    Precision = (TP/(TP+FP))
    Recall = (TP/(TP+FN))
    F1_Score = 2*((1/Recall)+(1/Precision))
    accuracy = (TN+TP)/(TN+TP+FP+FN)
    print("Precsion is          "+str(Precision))
    print("Recall is            "+str(Recall))
    print("F1_Score is          "+str(F1_Score))
    print("Accuracy is          "+str(accuracy))
    print("-------------------------------------------------")
    print("( Here 1's  are positive 0's are negative)")
    len(train)
# Out:
# Results On Training Data
# Using MissClassification Rate as impurity measure
# -------------------------------------------------
# True Positive are    2098
# True Negatives are   6795
# False Positive are   41
# False Negatives are  55
# Precsion is          0.9808321645628798
# Recall is            0.974454249883883
# F1_Score is          4.091515729265968
# Accuracy is          0.989320280342641
# -------------------------------------------------
# ( Here 1's  are positive 0's are negative)
# 8989

# %%
    GivenTestData =  val.copy()
    GivenTestData['predict']= [0]*len(GivenTestData)
    for i in list(GivenTestData.index.values):        
        GivenTestData.at[i,'predict'] = RecursiveFunctionToPredict(i,RootNode,GivenTestData)
    
    TN = 0
    FP = 0
    FN = 0
    TP = 0
    for i in list(GivenTestData.index.values):
        if str(GivenTestData.at[i,'left']) == str(1) and str(GivenTestData.at[i,'predict']) == str(1):
            TP = TP + 1
        elif str(GivenTestData.at[i,'left']) == str(1) and str(GivenTestData.at[i,'predict']) == str(0):
            FN = FN + 1
        elif str(GivenTestData.at[i,'left']) == str(0) and str(GivenTestData.at[i,'predict']) == str(1):
            FP = FP + 1
        elif str(GivenTestData.at[i,'left']) == str(0) and str(GivenTestData.at[i,'predict']) == str(0):
            TN = TN + 1
    print("Results On Validation Data")
    print("Using MissClassification Rate as impurity measure")
    print("-------------------------------------------------")
    print("True Positive are    "+ str(TP))
    print("True Negatives are   "+ str(TN))
    print("False Positive are   "+ str(FP))
    print("False Negatives are  "+str(FN))
    
    Precision = (TP/(TP+FP))
    Recall = (TP/(TP+FN))
    F1_Score = 2*((1/Recall)+(1/Precision))
    accuracy = (TN+TP)/(TN+TP+FP+FN)
    print("Precsion is          "+str(Precision))
    print("Recall is            "+str(Recall))
    print("F1_Score is          "+str(F1_Score))
    print("Accuracy is          "+str(accuracy))
    print("-------------------------------------------------")
    print("( Here 1's  are positive 0's are negative)")
    len(val)
# Out:
# Results On Validation Data
# Using MissClassification Rate as impurity measure
# -------------------------------------------------
# True Positive are    497
# True Negatives are   1689
# False Positive are   38
# False Negatives are  25
# Precsion is          0.9289719626168225
# Recall is            0.9521072796934866
# F1_Score is          4.253521126760564
# Accuracy is          0.9719875500222321
# -------------------------------------------------
# ( Here 1's  are positive 0's are negative)
# 2249
