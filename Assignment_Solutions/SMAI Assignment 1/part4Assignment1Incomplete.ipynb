# %%
import pandas as pd 
import numpy as np
data = pd.read_csv("train.csv")

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
 
x = list(data["number_project"])
y = list(data["satisfaction_level"])
z = list(data["average_montly_hours"])
p = [0]*len(x)
#z
#x = [1,2,3]
#y = [1,2,3]
label = list(data["left"])
#label = [0,1,0]
#colors= ['black' if l == 0 else 'yellow' for l in label]
colors =[]
for i in range(0,len(x)):
    if label[i] == 0:
        colors.append("yellow")
    else:
        colors.append("blue")
    
#colors= ['blue' if l == 0 else 'yellow' for l in label]
fig = plt.figure(figsize=(8,8))
plt.scatter(x, y, color=colors,alpha = 0.2)
fig1 = plt.figure(figsize=(8,8))
plt.scatter(x, y, color=colors,alpha = 0.2)
#plt.scatter(x, y, c=label, cmap=matplotlib.colors.ListedColormap(colors))
#['satisfaction_level', 'last_evaluation', 'number_project',
  #     'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
   #    'promotion_last_5years', 'department', 'salary']

# %%
l
