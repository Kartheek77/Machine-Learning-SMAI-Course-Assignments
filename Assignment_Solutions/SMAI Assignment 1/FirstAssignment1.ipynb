# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
import numpy as np
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("train.csv") 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.10             0.90               7                   286
# 1                0.89             0.93               4                   249
# 2                0.38             0.50               2                   132
# 3                0.95             0.71               4                   151
# 4                0.84             0.84               5                   163
#
#    time_spend_company  Work_accident  left  promotion_last_5years  department  \
# 0                   4              0     1                      0       sales
# 1                   3              0     0                      0       sales
# 2                   3              0     1                      0  accounting
# 3                   4              0     0                      0       sales
# 4                   3              0     0                      0   technical
#
#    salary
# 0     low
# 1     low
# 2     low
# 3  medium
# 4     low

# %%
data.at[4,'number_project']
data.iat[4,2]
# Out:
# 5

# %%
len(data.columns)
# Out:
# 10

# %%
msk = np.random.rand(len(data)) < 0.8
train = data[msk]
val = data[~msk]
print(len(train))
print(len(val))
train.head()
# Out:
# 8984
# 2254
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 1                0.89             0.93               4                   249
# 2                0.38             0.50               2                   132
# 3                0.95             0.71               4                   151
# 5                0.76             0.94               4                   168
# 6                0.55             0.88               4                   252
#
#    time_spend_company  Work_accident  left  promotion_last_5years  department  \
# 1                   3              0     0                      0       sales
# 2                   3              0     1                      0  accounting
# 3                   4              0     0                      0       sales
# 5                   6              0     0                      0   technical
# 6                   3              0     0                      0  management
#
#    salary
# 1     low
# 2     low
# 3  medium
# 5  medium
# 6     low

# %%
val.head()
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.10             0.90               7                   286
# 4                 0.84             0.84               5                   163
# 8                 0.17             0.85               3                   168
# 12                0.20             0.68               5                   167
# 16                0.93             0.87               3                   154
#
#     time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                    4              0     1                      0      sales
# 4                    3              0     0                      0  technical
# 8                    4              0     0                      0         IT
# 12                   7              0     0                      0  marketing
# 16                   3              1     0                      0         IT
#
#     salary
# 0      low
# 4      low
# 8      low
# 12  medium
# 16     low

# %%
train = train.loc[:,['Work_accident', 'promotion_last_5years', 'department', 'salary','left'] ] 
print(train.head())
val = val.loc[:,['Work_accident', 'promotion_last_5years', 'department', 'salary','left'] ] 
print(val.head())
# Out:
#    Work_accident  promotion_last_5years  department  salary  left
# 1              0                      0       sales     low     0
# 2              0                      0  accounting     low     1
# 3              0                      0       sales  medium     0
# 5              0                      0   technical  medium     0
# 6              0                      0  management     low     0
#     Work_accident  promotion_last_5years department  salary  left
# 0               0                      0      sales     low     1
# 4               0                      0  technical     low     0
# 8               0                      0         IT     low     0
# 12              0                      0  marketing  medium     0
# 16              1                      0         IT     low     0

# %%
#class DecisionTreeForDTClassifier:
#   def __init__(self,)
depAttValue = train["department"].unique()
print(depAttValue)
len(depAttValue)
# Out:
# ['sales' 'accounting' 'technical' 'management' 'product_mng' 'IT' 'RandD'
#  'marketing' 'support' 'hr']
# 10

# %%
#Implement the solution using scikit learn algorithm
numberOfNodes = 0

# %%
class Node(object):
    def __init__(self, label,name):
        self.name = name
        self.label = label
        self.children = []

    def add_child(self, obj):
        self.children.append(obj)
        
    def __str__(self):
        return self.label +" "+ self.name

# %%
targetAttribute = 'left'
Attributes = list(train.columns)
Attributes.remove(targetAttribute)
AllAttrExpTar = Attributes[:]
print(Attributes)
examples = list(train.index.values) 
len(examples)
# Out:
# ['Work_accident', 'promotion_last_5years', 'department', 'salary']
# 8984

# %%
def getEntropyofAttribute(currentAttribute,examplesForCurAttr,targetAttribute):
    NumberOfexamplesForCurAttr = len(examplesForCurAttr)
    sum = 0.0
    fra1 = train.loc[examplesForCurAttr,[currentAttribute] ]
    currentAttributeValues = fra1[currentAttribute].unique()
    for i in currentAttributeValues:
        NumberOfPosForThisValue = 0
        NumberOfNegForThisValue = 0
        for j in examplesForCurAttr:
            if  train.at[int(j),targetAttribute] == 1:
                NumberOfPosForThisValue = NumberOfPosForThisValue+1
            else:
                NumberOfNegForThisValue = NumberOfNegForThisValue+1
        PropOfPos = NumberOfPosForThisValue/NumberOfexamplesForCurAttr
        PropOfNeg = NumberOfNegForThisValue/NumberOfexamplesForCurAttr
        sum = sum + (-1*PropOfPos*(np.log(PropOfPos)/np.log(2))) + (-1*PropOfNeg*(np.log(PropOfNeg)/np.log(2)))
    return sum

# %%
(np.log(4)/np.log(2))
# Out:
# 2.0

# %%
def BestOfAttributes(Attributes,examplesForCurAttr,targetAttribute,method):
    if method == 'Entropy':
        EntropyForAttributes = {}
        for i in Attributes:
            EntropyForAttributes[i] = getEntropyofAttribute(i,examplesForCurAttr,targetAttribute)
        #findining the minimum among entropy of attributes
        BestOfAttributes = min(EntropyForAttributes, key=EntropyForAttributes.get)
        return BestOfAttributes        
    elif method == 'Gini':
        pass
    elif method == 'misClasifi':
        pass
    return BestOfAttributes

# %%
train.at[2,'left']

# %%
def DecisionTreeBuilder(examplesForCurAttr,targetAttribute,Attributes):
    # if all examplesForCurAttr are positive(i.e employee left the company,left =1 )
    global numberOfNodes
    allExPos = True
    for i in examplesForCurAttr:
        if train.at[i,targetAttribute] == 1:
            pass
        else:
            allExPos = False
            break
    if allExPos:
        r = Node('Positive','leaf Node')
        numberOfNodes  = numberOfNodes + 1
        print("********************************************************************")
        print("The label of current node is")
        print(r)
        print("number of examplesForCurAttr of this attribute is ")
        print(len(examplesForCurAttr))
        #print(examplesForCurAttr)
        print("Type1")
        print("********************************************************************")    
        return r
    
    # if all examplesForCurAttr are negative(i.e employee didnot leave the company,left =0 )
    allExNeg = True
    for j in examplesForCurAttr:
        if (train.at[j,targetAttribute] == 0):
            pass
        else:
            allExNeg = False
            break
    if allExNeg:
        r = Node('Negative','leaf Node')
        numberOfNodes  = numberOfNodes + 1
        print("********************************************************************")
        print("The label of current node is")
        print(r)
        print("number of examplesForCurAttr of this attribute is ")
        print(len(examplesForCurAttr))
        #print(examplesForCurAttr)
        print("Type2")
        print("********************************************************************")
        return r
    
    #if attributes are empty , then most common value of target Attribute in examplesForCurAttr
    if len(Attributes) == 0:
    #if len(examplesForCurAttr)< 100: 
        fra1 = train.loc[examplesForCurAttr,[targetAttribute] ]
        targetAttributesList = fra1[targetAttribute].values
        unique1, counts1 = np.unique(targetAttributesList, return_counts=True)
        dictOfTaAttr = dict(zip(unique1, counts1))
        posCount = dictOfTaAttr[1]
        negCount = dictOfTaAttr[0]
        if posCount>negCount:
            r = Node('Positive','leaf Node')
            numberOfNodes  = numberOfNodes + 1
        else:
            r = Node('Negative','leaf Node')
            numberOfNodes  = numberOfNodes + 1
        print("********************************************************************")
        print("The label of current node is")
        print(r)
        print("number of examplesForCurAttr of this attribute is ")
        print(len(examplesForCurAttr))
        #print(examplesForCurAttr)
        print("Type3")
        print("********************************************************************")
        return r
    #if len(Attributes) == 0:
        #Attributes = Attributes + AllAttrExpTar
    
    BestAttribute = BestOfAttributes(Attributes,examplesForCurAttr,targetAttribute,'Entropy')
    Attributes.remove(BestAttribute)    
    r = Node(BestAttribute,'internalNode')
    numberOfNodes  = numberOfNodes + 1
    BestAttributeValues = train[BestAttribute].unique()
    for iter in BestAttributeValues:
        examplesForCurAttrForThisChild = []
        for iter1 in examplesForCurAttr:
            if  train.at[int(iter1),str(BestAttribute)] == iter:
                examplesForCurAttrForThisChild.append(int(iter1)) 
        r.add_child(DecisionTreeBuilder(examplesForCurAttrForThisChild,targetAttribute,Attributes))
    print("********************************************************************")
    print("The label of current node is")
    print(r)
    print("the best decision attribute of current node is")
    print(BestAttribute)
    print("number of examplesForCurAttr of this attribute is ")
    print(len(examplesForCurAttr))
    #print(examplesForCurAttr)
    print("children of current nodes")
    plabo = range(0,len(r.children))
    for k in plabo:
        print(r.children[k])
    print("Type4")
    print("********************************************************************")
            
    return r

# %%
RootNode = DecisionTreeBuilder(examples,'left',Attributes) 
numberOfNodes
# Out:
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 1108
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 184
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 692
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 91
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 225
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 321
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 165
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 180
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 576
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 176
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# department internalNode
# the best decision attribute of current node is
# department
# number of examplesForCurAttr of this attribute is
# 3718
# children of current nodes
# Negative leaf Node
# Negative leaf Node
# Negative leaf Node
# Negative leaf Node
# Negative leaf Node
# Negative leaf Node
# Negative leaf Node
# Negative leaf Node
# Negative leaf Node
# Negative leaf Node
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 3212
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 597
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# salary internalNode
# the best decision attribute of current node is
# salary
# number of examplesForCurAttr of this attribute is
# 7527
# children of current nodes
# department internalNode
# Negative leaf Node
# Negative leaf Node
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 147
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years internalNode
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 7674
# children of current nodes
# salary internalNode
# Negative leaf Node
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative leaf Node
# number of examplesForCurAttr of this attribute is
# 1310
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Work_accident internalNode
# the best decision attribute of current node is
# Work_accident
# number of examplesForCurAttr of this attribute is
# 8984
# children of current nodes
# promotion_last_5years internalNode
# Negative leaf Node
# Type4
# ********************************************************************
# 49

# %%
# validation 
#first predict the target value for each sample(for given set of attributes) using the decision tree constructed
#then calculate precision, recall, f1 score , accuracy

# %%
prediction = {}
examplesOfVal = list(val.index.values)

# %%
print(RootNode)
print(len(RootNode.children))
# Out:
# department internalNode
# 10

# %%
boto = RootNode
totallength = len(boto.children[0].children)
print(totallength)
plabo = range(0,totallength)
for k in plabo:
    print(boto.children[0].children[k])
# Out:
# 3
# Work_accident internalNode
# Negative leaf Node
# Negative leaf Node

# %%
#!/usr/bin/env python
# coding: utf-8

# In[89]:


# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
import numpy as np
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("train.csv") 
# Preview the first 5 lines of the loaded data 
data.head()


# In[90]:


data.at[4,'number_project']
data.iat[4,2]


# In[91]:


len(data.columns)


# In[92]:


msk = np.random.rand(len(data)) < 0.8
train = data[msk]
val = data[~msk]
print(len(train))
print(len(val))
train.head()


# In[93]:


val.head()


# In[179]:


train = train.loc[:,['Work_accident', 'promotion_last_5years', 'department', 'salary','left'] ] 
print(train.head())
val = val.loc[:,['Work_accident', 'promotion_last_5years', 'department', 'salary','left'] ] 
print(val.head())


# In[95]:


#class DecisionTreeForDTClassifier:
#   def __init__(self,)
depAttValue = train["department"].unique()
print(depAttValue)
len(depAttValue)


# In[186]:


#Implement the solution using scikit learn algorithm
numberOfNodes = 0


# In[96]:


class Node(object):
    def __init__(self, label,name,parentAttrValue,nodeNumber):
        self.name = name
        self.label = label
        self.parentAttrValue = parentAttrValue 
        self.nodeNumber = nodeNumber
        self.children = []

    def add_child(self, obj):
        self.children.append(obj)
        
    def __str__(self):
        return self.label +"  "+ self.name+"  "+self.parentAttrValue+"Node number is "+ str(self.nodeNumber)


targetAttribute = 'left'
Attributes = list(train.columns)
Attributes.remove(targetAttribute)
AllAttrExpTar = Attributes[:]
print(Attributes)
examples = list(train.index.values) 
len(examples)



def getEntropyofAttribute(currentAttribute,examplesForCurAttr,targetAttribute):
    NumberOfexamplesForCurAttr = len(examplesForCurAttr)
    sum = 0.0
    fra1 = train.loc[examplesForCurAttr,[currentAttribute] ]
    currentAttributeValues = fra1[currentAttribute].unique()
    #currentAttributeList = fra1[currentAttribute]
    #unique2, counts2 = np.unique(currentAttributesList, return_counts=True)
    #dictOfAttr = dict(zip(unique2, counts2))
    print("currentAttribute is "+currentAttribute+" and its values are")
    print(currentAttributeValues)
    for i in currentAttributeValues:
    #for i in unique2:
        NumberOfExaForThisValue = 0
        for j in examplesForCurAttr:
            if train.at[int(j),currentAttribute] == i:
                NumberOfExaForThisValue = NumberOfExaForThisValue+1
        if NumberOfExaForThisValue == 0:
            sum = sum+0
        else:
            NumberOfPosForThisValue = 0
            NumberOfNegForThisValue = 0
            for j in examplesForCurAttr:
                if  train.at[int(j),targetAttribute] == 1 and train.at[int(j),currentAttribute] == i:
                    NumberOfPosForThisValue = NumberOfPosForThisValue+1
                elif train.at[int(j),targetAttribute] == 0 and train.at[int(j),currentAttribute] == i:
                    NumberOfNegForThisValue = NumberOfNegForThisValue+1
            PropOfPos = NumberOfPosForThisValue/NumberOfExaForThisValue
            PropOfNeg = NumberOfNegForThisValue/NumberOfExaForThisValue
            PropOfThisValue = NumberOfExaForThisValue/NumberOfexamplesForCurAttr
            #print("PropOfPos "+str(PropOfPos)+" PropOfNeg "+str(PropOfNeg)+"NumberOfexamplesForCurAttr "+str(NumberOfexamplesForCurAttr))
            sum = sum + ((PropOfThisValue)*((-1*PropOfPos*(np.log(PropOfPos)/np.log(2))) + (-1*PropOfNeg*(np.log(PropOfNeg)/np.log(2)))))
    return sum


# In[99]:


(np.log(4)/np.log(2))


# In[120]:


def BestOfAttributes(Attributes,examplesForCurAttr,targetAttribute,method):
    if len(Attributes) == 1:
        return Attributes[0]
    elif method == 'Entropy':
        EntropyForAttributes = {}
        for i in Attributes:
            EntropyForAttributes[i] = getEntropyofAttribute(i,examplesForCurAttr,targetAttribute)
        #findining the minimum among entropy of attributes
        #print("entropy of attributes")
        #print(EntropyForAttributes)
        BestOfAttributes = min(EntropyForAttributes, key=EntropyForAttributes.get)
        return BestOfAttributes        
    elif method == 'Gini':
        pass
    elif method == 'misClasifi':
        pass
    return BestOfAttributes


# In[167]:


#train.at[2,'left']


# In[193]:


def DecisionTreeBuilder(examplesForCurAttr,targetAttribute,Attributes,parentAttrValue):
    # if all examplesForCurAttr are positive(i.e employee left the company,left =1 )
    global numberOfNodes
    allExPos = True
    for i in examplesForCurAttr:
        if train.at[i,targetAttribute] == 1:
            pass
        else:
            allExPos = False
            break
    if allExPos:
        r = Node('Positive','leaf Node',parentAttrValue,numberOfNodes)
        numberOfNodes  = numberOfNodes + 1
        print("********************************************************************")
        print("The label of current node is")
        print(r)
        print("number of examplesForCurAttr of this attribute is ")
        print(len(examplesForCurAttr))
        #print(examplesForCurAttr)
        print("Type1")
        print("********************************************************************")    
        return r
    
    # if all examplesForCurAttr are negative(i.e employee didnot leave the company,left =0 )
    allExNeg = True
    for j in examplesForCurAttr:
        if (train.at[j,targetAttribute] == 0):
            pass
        else:
            allExNeg = False
            break
    if allExNeg:
        r = Node('Negative','leaf Node',parentAttrValue,numberOfNodes)
        numberOfNodes  = numberOfNodes + 1
        print("********************************************************************")
        print("The label of current node is")
        print(r)
        print("number of examplesForCurAttr of this attribute is ")
        print(len(examplesForCurAttr))
        #print(examplesForCurAttr)
        print("Type2")
        print("********************************************************************")
        return r
    
    #if attributes are empty , then most common value of target Attribute in examplesForCurAttr
    if len(Attributes) == 0 or len(examplesForCurAttr)<50:
        fra1 = train.loc[examplesForCurAttr,[targetAttribute] ]
        targetAttributesList = fra1[targetAttribute].values
        unique1, counts1 = np.unique(targetAttributesList, return_counts=True)
        dictOfTaAttr = dict(zip(unique1, counts1))
        posCount = dictOfTaAttr[1]
        negCount = dictOfTaAttr[0]
        if posCount>negCount:
            r = Node('Positive','leaf Node',parentAttrValue,numberOfNodes)
            numberOfNodes  = numberOfNodes + 1
        else:
            r = Node('Negative','leaf Node',parentAttrValue,numberOfNodes)
            numberOfNodes  = numberOfNodes + 1
        print("********************************************************************")
        print("The label of current node is")
        print(r)
        print("number of examplesForCurAttr of this attribute is ")
        print(len(examplesForCurAttr))
        #print(examplesForCurAttr)
        #print("PosCount "+str(posCount)+"and "+str(negCount)+" negCount")
        print("Type3")
        print("********************************************************************")
        return r
    #if len(Attributes) == 0:
    #else:
        #Attributes = Attributes + AllAttrExpTar
    
    BestAttribute = BestOfAttributes(Attributes,examplesForCurAttr,targetAttribute,'Entropy')
    Attributes.remove(BestAttribute)    
    r = Node(BestAttribute,'internalNode',parentAttrValue,numberOfNodes)
    numberOfNodes  = numberOfNodes + 1
    BestAttributeValues = list(train[BestAttribute].unique())
    for iter in BestAttributeValues:
        AttributesForNextNodes = []
        AttributesForNextNode = Attributes[:]
        examplesForCurAttrForThisChild = []
        for iter1 in examplesForCurAttr:
            if  train.at[int(iter1),str(BestAttribute)] == iter:
                examplesForCurAttrForThisChild.append(int(iter1)) 
        tempstr = str(iter)+str(BestAttribute)
        r.add_child(DecisionTreeBuilder(examplesForCurAttrForThisChild,targetAttribute,AttributesForNextNode,tempstr))
    print("********************************************************************")
    print("The label of current node is")
    print(r)
    print("the best decision attribute of current node is")
    print(BestAttribute)
    print("number of examplesForCurAttr of this attribute is ")
    print(len(examplesForCurAttr))
    #print(examplesForCurAttr)
    print("children of current nodes")
    plabo = range(0,len(r.children))
    for k in plabo:
        print(r.children[k])
    print("Type4")
    print("********************************************************************")
            
    return r


# In[194]:


RootNode = DecisionTreeBuilder(examples,'left',Attributes,'root') 
numberOfNodes
# Out:
# 8997
# 2241
#    Work_accident  promotion_last_5years  department  salary  left
# 1              0                      0       sales     low     0
# 2              0                      0  accounting     low     1
# 4              0                      0   technical     low     0
# 5              0                      0   technical  medium     0
# 6              0                      0  management     low     0
#     Work_accident  promotion_last_5years   department  salary  left
# 0               0                      0        sales     low     1
# 3               0                      0        sales  medium     0
# 7               0                      0        sales  medium     0
# 22              0                      0           IT     low     0
# 28              0                      0  product_mng  medium     0
# ['sales' 'accounting' 'technical' 'management' 'IT' 'product_mng'
#  'marketing' 'RandD' 'support' 'hr']
# ['Work_accident', 'promotion_last_5years', 'department', 'salary']
# currentAttribute is Work_accident and its values are
# [0 1]
# currentAttribute is promotion_last_5years and its values are
# [0 1]
# currentAttribute is department and its values are
# ['sales' 'accounting' 'technical' 'management' 'IT' 'product_mng'
#  'marketing' 'RandD' 'support' 'hr']
# currentAttribute is salary and its values are
# ['low' 'medium' 'high']
# currentAttribute is Work_accident and its values are
# [0 1]
# currentAttribute is promotion_last_5years and its values are
# [0 1]
# currentAttribute is department and its values are
# ['sales' 'accounting' 'technical' 'management' 'IT' 'product_mng' 'RandD'
#  'marketing' 'support' 'hr']
# currentAttribute is promotion_last_5years and its values are
# [0 1]
# currentAttribute is department and its values are
# ['sales' 'accounting' 'technical' 'management' 'IT' 'product_mng' 'RandD'
#  'marketing' 'support' 'hr']
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 4
# number of examplesForCurAttr of this attribute is
# 1105
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 5
# number of examplesForCurAttr of this attribute is
# 7
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  salesdepartmentNode number is 3
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 1112
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 4
# Negative  leaf Node  1promotion_last_5yearsNode number is 5
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 7
# number of examplesForCurAttr of this attribute is
# 192
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Positive  leaf Node  1promotion_last_5yearsNode number is 8
# number of examplesForCurAttr of this attribute is
# 0
# Type1
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  accountingdepartmentNode number is 6
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 192
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 7
# Positive  leaf Node  1promotion_last_5yearsNode number is 8
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 10
# number of examplesForCurAttr of this attribute is
# 691
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 11
# number of examplesForCurAttr of this attribute is
# 4
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  technicaldepartmentNode number is 9
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 695
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 10
# Negative  leaf Node  1promotion_last_5yearsNode number is 11
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 13
# number of examplesForCurAttr of this attribute is
# 92
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Positive  leaf Node  1promotion_last_5yearsNode number is 14
# number of examplesForCurAttr of this attribute is
# 1
# Type1
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  managementdepartmentNode number is 12
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 93
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 13
# Positive  leaf Node  1promotion_last_5yearsNode number is 14
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 16
# number of examplesForCurAttr of this attribute is
# 321
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Positive  leaf Node  1promotion_last_5yearsNode number is 17
# number of examplesForCurAttr of this attribute is
# 1
# Type1
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  ITdepartmentNode number is 15
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 322
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 16
# Positive  leaf Node  1promotion_last_5yearsNode number is 17
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 19
# number of examplesForCurAttr of this attribute is
# 235
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Positive  leaf Node  1promotion_last_5yearsNode number is 20
# number of examplesForCurAttr of this attribute is
# 0
# Type1
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  product_mngdepartmentNode number is 18
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 235
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 19
# Positive  leaf Node  1promotion_last_5yearsNode number is 20
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 22
# number of examplesForCurAttr of this attribute is
# 178
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 23
# number of examplesForCurAttr of this attribute is
# 7
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  marketingdepartmentNode number is 21
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 185
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 22
# Negative  leaf Node  1promotion_last_5yearsNode number is 23
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 25
# number of examplesForCurAttr of this attribute is
# 170
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 26
# number of examplesForCurAttr of this attribute is
# 1
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  RandDdepartmentNode number is 24
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 171
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 25
# Negative  leaf Node  1promotion_last_5yearsNode number is 26
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 28
# number of examplesForCurAttr of this attribute is
# 562
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 29
# number of examplesForCurAttr of this attribute is
# 4
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  supportdepartmentNode number is 27
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 566
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 28
# Negative  leaf Node  1promotion_last_5yearsNode number is 29
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 31
# number of examplesForCurAttr of this attribute is
# 172
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 32
# number of examplesForCurAttr of this attribute is
# 1
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  hrdepartmentNode number is 30
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 173
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 31
# Negative  leaf Node  1promotion_last_5yearsNode number is 32
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# department  internalNode  0Work_accidentNode number is 2
# the best decision attribute of current node is
# department
# number of examplesForCurAttr of this attribute is
# 3744
# children of current nodes
# promotion_last_5years  internalNode  salesdepartmentNode number is 3
# promotion_last_5years  internalNode  accountingdepartmentNode number is 6
# promotion_last_5years  internalNode  technicaldepartmentNode number is 9
# promotion_last_5years  internalNode  managementdepartmentNode number is 12
# promotion_last_5years  internalNode  ITdepartmentNode number is 15
# promotion_last_5years  internalNode  product_mngdepartmentNode number is 18
# promotion_last_5years  internalNode  marketingdepartmentNode number is 21
# promotion_last_5years  internalNode  RandDdepartmentNode number is 24
# promotion_last_5years  internalNode  supportdepartmentNode number is 27
# promotion_last_5years  internalNode  hrdepartmentNode number is 30
# Type4
# ********************************************************************
# currentAttribute is promotion_last_5years and its values are
# [0 1]
# currentAttribute is department and its values are
# ['IT' 'sales' 'marketing' 'technical' 'RandD' 'support' 'product_mng'
#  'accounting' 'management' 'hr']
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 35
# number of examplesForCurAttr of this attribute is
# 171
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 36
# number of examplesForCurAttr of this attribute is
# 4
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  salesdepartmentNode number is 34
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 175
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 35
# Negative  leaf Node  1promotion_last_5yearsNode number is 36
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  accountingdepartmentNode number is 37
# number of examplesForCurAttr of this attribute is
# 29
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 39
# number of examplesForCurAttr of this attribute is
# 104
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 40
# number of examplesForCurAttr of this attribute is
# 1
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  technicaldepartmentNode number is 38
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 105
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 39
# Negative  leaf Node  1promotion_last_5yearsNode number is 40
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  managementdepartmentNode number is 41
# number of examplesForCurAttr of this attribute is
# 21
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 43
# number of examplesForCurAttr of this attribute is
# 51
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Positive  leaf Node  1promotion_last_5yearsNode number is 44
# number of examplesForCurAttr of this attribute is
# 0
# Type1
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  ITdepartmentNode number is 42
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 51
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 43
# Positive  leaf Node  1promotion_last_5yearsNode number is 44
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  product_mngdepartmentNode number is 45
# number of examplesForCurAttr of this attribute is
# 42
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  marketingdepartmentNode number is 46
# number of examplesForCurAttr of this attribute is
# 41
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  RandDdepartmentNode number is 47
# number of examplesForCurAttr of this attribute is
# 37
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 49
# number of examplesForCurAttr of this attribute is
# 102
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Positive  leaf Node  1promotion_last_5yearsNode number is 50
# number of examplesForCurAttr of this attribute is
# 0
# Type1
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  supportdepartmentNode number is 48
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 102
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 49
# Positive  leaf Node  1promotion_last_5yearsNode number is 50
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  hrdepartmentNode number is 51
# number of examplesForCurAttr of this attribute is
# 26
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# department  internalNode  1Work_accidentNode number is 33
# the best decision attribute of current node is
# department
# number of examplesForCurAttr of this attribute is
# 629
# children of current nodes
# promotion_last_5years  internalNode  salesdepartmentNode number is 34
# Negative  leaf Node  accountingdepartmentNode number is 37
# promotion_last_5years  internalNode  technicaldepartmentNode number is 38
# Negative  leaf Node  managementdepartmentNode number is 41
# promotion_last_5years  internalNode  ITdepartmentNode number is 42
# Negative  leaf Node  product_mngdepartmentNode number is 45
# Negative  leaf Node  marketingdepartmentNode number is 46
# Negative  leaf Node  RandDdepartmentNode number is 47
# promotion_last_5years  internalNode  supportdepartmentNode number is 48
# Negative  leaf Node  hrdepartmentNode number is 51
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Work_accident  internalNode  lowsalaryNode number is 1
# the best decision attribute of current node is
# Work_accident
# number of examplesForCurAttr of this attribute is
# 4373
# children of current nodes
# department  internalNode  0Work_accidentNode number is 2
# department  internalNode  1Work_accidentNode number is 33
# Type4
# ********************************************************************
# currentAttribute is Work_accident and its values are
# [0 1]
# currentAttribute is promotion_last_5years and its values are
# [0 1]
# currentAttribute is department and its values are
# ['technical' 'marketing' 'IT' 'sales' 'RandD' 'hr' 'support' 'accounting'
#  'product_mng' 'management']
# currentAttribute is promotion_last_5years and its values are
# [0 1]
# currentAttribute is department and its values are
# ['technical' 'marketing' 'IT' 'sales' 'RandD' 'hr' 'support' 'accounting'
#  'product_mng' 'management']
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 55
# number of examplesForCurAttr of this attribute is
# 863
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 56
# number of examplesForCurAttr of this attribute is
# 28
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  salesdepartmentNode number is 54
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 891
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 55
# Negative  leaf Node  1promotion_last_5yearsNode number is 56
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 58
# number of examplesForCurAttr of this attribute is
# 168
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 59
# number of examplesForCurAttr of this attribute is
# 3
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  accountingdepartmentNode number is 57
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 171
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 58
# Negative  leaf Node  1promotion_last_5yearsNode number is 59
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 61
# number of examplesForCurAttr of this attribute is
# 583
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 62
# number of examplesForCurAttr of this attribute is
# 8
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  technicaldepartmentNode number is 60
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 591
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 61
# Negative  leaf Node  1promotion_last_5yearsNode number is 62
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 64
# number of examplesForCurAttr of this attribute is
# 105
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 65
# number of examplesForCurAttr of this attribute is
# 11
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  managementdepartmentNode number is 63
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 116
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 64
# Negative  leaf Node  1promotion_last_5yearsNode number is 65
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 67
# number of examplesForCurAttr of this attribute is
# 273
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Positive  leaf Node  1promotion_last_5yearsNode number is 68
# number of examplesForCurAttr of this attribute is
# 0
# Type1
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  ITdepartmentNode number is 66
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 273
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 67
# Positive  leaf Node  1promotion_last_5yearsNode number is 68
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 70
# number of examplesForCurAttr of this attribute is
# 192
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Positive  leaf Node  1promotion_last_5yearsNode number is 71
# number of examplesForCurAttr of this attribute is
# 0
# Type1
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  product_mngdepartmentNode number is 69
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 192
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 70
# Positive  leaf Node  1promotion_last_5yearsNode number is 71
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 73
# number of examplesForCurAttr of this attribute is
# 178
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 74
# number of examplesForCurAttr of this attribute is
# 14
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  marketingdepartmentNode number is 72
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 192
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 73
# Negative  leaf Node  1promotion_last_5yearsNode number is 74
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 76
# number of examplesForCurAttr of this attribute is
# 183
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 77
# number of examplesForCurAttr of this attribute is
# 11
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  RandDdepartmentNode number is 75
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 194
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 76
# Negative  leaf Node  1promotion_last_5yearsNode number is 77
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 79
# number of examplesForCurAttr of this attribute is
# 485
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 80
# number of examplesForCurAttr of this attribute is
# 7
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  supportdepartmentNode number is 78
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 492
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 79
# Negative  leaf Node  1promotion_last_5yearsNode number is 80
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  0promotion_last_5yearsNode number is 82
# number of examplesForCurAttr of this attribute is
# 183
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 83
# number of examplesForCurAttr of this attribute is
# 5
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  hrdepartmentNode number is 81
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 188
# children of current nodes
# Negative  leaf Node  0promotion_last_5yearsNode number is 82
# Negative  leaf Node  1promotion_last_5yearsNode number is 83
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# department  internalNode  0Work_accidentNode number is 53
# the best decision attribute of current node is
# department
# number of examplesForCurAttr of this attribute is
# 3300
# children of current nodes
# promotion_last_5years  internalNode  salesdepartmentNode number is 54
# promotion_last_5years  internalNode  accountingdepartmentNode number is 57
# promotion_last_5years  internalNode  technicaldepartmentNode number is 60
# promotion_last_5years  internalNode  managementdepartmentNode number is 63
# promotion_last_5years  internalNode  ITdepartmentNode number is 66
# promotion_last_5years  internalNode  product_mngdepartmentNode number is 69
# promotion_last_5years  internalNode  marketingdepartmentNode number is 72
# promotion_last_5years  internalNode  RandDdepartmentNode number is 75
# promotion_last_5years  internalNode  supportdepartmentNode number is 78
# promotion_last_5years  internalNode  hrdepartmentNode number is 81
# Type4
# ********************************************************************
# currentAttribute is promotion_last_5years and its values are
# [0 1]
# currentAttribute is department and its values are
# ['support' 'technical' 'sales' 'IT' 'hr' 'management' 'RandD' 'accounting'
#  'marketing' 'product_mng']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:132: RuntimeWarning: divide by zero encountered in log
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:132: RuntimeWarning: invalid value encountered in double_scalars
# ********************************************************************
# The label of current node is
# Negative  leaf Node  salesdepartmentNode number is 86
# number of examplesForCurAttr of this attribute is
# 154
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  accountingdepartmentNode number is 87
# number of examplesForCurAttr of this attribute is
# 31
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  technicaldepartmentNode number is 88
# number of examplesForCurAttr of this attribute is
# 94
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  managementdepartmentNode number is 89
# number of examplesForCurAttr of this attribute is
# 24
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  ITdepartmentNode number is 90
# number of examplesForCurAttr of this attribute is
# 40
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  product_mngdepartmentNode number is 91
# number of examplesForCurAttr of this attribute is
# 28
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  marketingdepartmentNode number is 92
# number of examplesForCurAttr of this attribute is
# 28
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  RandDdepartmentNode number is 93
# number of examplesForCurAttr of this attribute is
# 29
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  supportdepartmentNode number is 94
# number of examplesForCurAttr of this attribute is
# 78
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  hrdepartmentNode number is 95
# number of examplesForCurAttr of this attribute is
# 19
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# department  internalNode  0promotion_last_5yearsNode number is 85
# the best decision attribute of current node is
# department
# number of examplesForCurAttr of this attribute is
# 525
# children of current nodes
# Negative  leaf Node  salesdepartmentNode number is 86
# Negative  leaf Node  accountingdepartmentNode number is 87
# Negative  leaf Node  technicaldepartmentNode number is 88
# Negative  leaf Node  managementdepartmentNode number is 89
# Negative  leaf Node  ITdepartmentNode number is 90
# Negative  leaf Node  product_mngdepartmentNode number is 91
# Negative  leaf Node  marketingdepartmentNode number is 92
# Negative  leaf Node  RandDdepartmentNode number is 93
# Negative  leaf Node  supportdepartmentNode number is 94
# Negative  leaf Node  hrdepartmentNode number is 95
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 96
# number of examplesForCurAttr of this attribute is
# 25
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  1Work_accidentNode number is 84
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 550
# children of current nodes
# department  internalNode  0promotion_last_5yearsNode number is 85
# Negative  leaf Node  1promotion_last_5yearsNode number is 96
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Work_accident  internalNode  mediumsalaryNode number is 52
# the best decision attribute of current node is
# Work_accident
# number of examplesForCurAttr of this attribute is
# 3850
# children of current nodes
# department  internalNode  0Work_accidentNode number is 53
# promotion_last_5years  internalNode  1Work_accidentNode number is 84
# Type4
# ********************************************************************
# currentAttribute is Work_accident and its values are
# [0 1]
# currentAttribute is promotion_last_5years and its values are
# [0 1]
# currentAttribute is department and its values are
# ['accounting' 'support' 'technical' 'sales' 'IT' 'management' 'marketing'
#  'hr' 'RandD' 'product_mng']
# currentAttribute is promotion_last_5years and its values are
# [0 1]
# currentAttribute is department and its values are
# ['accounting' 'support' 'technical' 'sales' 'IT' 'management' 'marketing'
#  'hr' 'RandD' 'product_mng']
# ********************************************************************
# The label of current node is
# Negative  leaf Node  salesdepartmentNode number is 100
# number of examplesForCurAttr of this attribute is
# 140
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  accountingdepartmentNode number is 101
# number of examplesForCurAttr of this attribute is
# 42
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  technicaldepartmentNode number is 102
# number of examplesForCurAttr of this attribute is
# 107
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  managementdepartmentNode number is 103
# number of examplesForCurAttr of this attribute is
# 102
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  ITdepartmentNode number is 104
# number of examplesForCurAttr of this attribute is
# 47
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  product_mngdepartmentNode number is 105
# number of examplesForCurAttr of this attribute is
# 34
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  marketingdepartmentNode number is 106
# number of examplesForCurAttr of this attribute is
# 29
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  RandDdepartmentNode number is 107
# number of examplesForCurAttr of this attribute is
# 26
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  supportdepartmentNode number is 108
# number of examplesForCurAttr of this attribute is
# 77
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  hrdepartmentNode number is 109
# number of examplesForCurAttr of this attribute is
# 21
# Type3
# ********************************************************************
# ********************************************************************
# The label of current node is
# department  internalNode  0promotion_last_5yearsNode number is 99
# the best decision attribute of current node is
# department
# number of examplesForCurAttr of this attribute is
# 625
# children of current nodes
# Negative  leaf Node  salesdepartmentNode number is 100
# Negative  leaf Node  accountingdepartmentNode number is 101
# Negative  leaf Node  technicaldepartmentNode number is 102
# Negative  leaf Node  managementdepartmentNode number is 103
# Negative  leaf Node  ITdepartmentNode number is 104
# Negative  leaf Node  product_mngdepartmentNode number is 105
# Negative  leaf Node  marketingdepartmentNode number is 106
# Negative  leaf Node  RandDdepartmentNode number is 107
# Negative  leaf Node  supportdepartmentNode number is 108
# Negative  leaf Node  hrdepartmentNode number is 109
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1promotion_last_5yearsNode number is 110
# number of examplesForCurAttr of this attribute is
# 29
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# promotion_last_5years  internalNode  0Work_accidentNode number is 98
# the best decision attribute of current node is
# promotion_last_5years
# number of examplesForCurAttr of this attribute is
# 654
# children of current nodes
# department  internalNode  0promotion_last_5yearsNode number is 99
# Negative  leaf Node  1promotion_last_5yearsNode number is 110
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# Negative  leaf Node  1Work_accidentNode number is 111
# number of examplesForCurAttr of this attribute is
# 120
# Type2
# ********************************************************************
# ********************************************************************
# The label of current node is
# Work_accident  internalNode  highsalaryNode number is 97
# the best decision attribute of current node is
# Work_accident
# number of examplesForCurAttr of this attribute is
# 774
# children of current nodes
# promotion_last_5years  internalNode  0Work_accidentNode number is 98
# Negative  leaf Node  1Work_accidentNode number is 111
# Type4
# ********************************************************************
# ********************************************************************
# The label of current node is
# salary  internalNode  rootNode number is 0
# the best decision attribute of current node is
# salary
# number of examplesForCurAttr of this attribute is
# 8997
# children of current nodes
# Work_accident  internalNode  lowsalaryNode number is 1
# Work_accident  internalNode  mediumsalaryNode number is 52
# Work_accident  internalNode  highsalaryNode number is 97
# Type4
# ********************************************************************
# 112

# %%
for k in range(0,len(RootNode.children)):
    print(RootNode.children[k])
print(RootNode.children[1])
# Out:
# Work_accident  internalNode  lowsalaryNode number is 1
# Negative  leaf Node  mediumsalaryNode number is 16
# Negative  leaf Node  highsalaryNode number is 17
# Negative  leaf Node  mediumsalaryNode number is 16

# %%
tempList1 = []
for k in examples:
    if train.at[int(k),'salary'] == 'high':
        tempList1.append(int(k)
